# %% [markdown]
# # Analyze Pairs Trading Results
#
# This notebook goes through the results produced, and previews the values obtained.

# %%
import pandas as pd

# %% [markdown]
# ## Summary over all pairs

# %%
df = pd.read_excel('summary/results.xlsx', )
df = df.set_index('Date')

# %% [markdown]
# ## Described by pair
#
# Each run stores a `Dataframe` containing information per pair involved on a trade. This dataframes are store on `summary/dfs/time_of_creation` and can be read as follows:

# %%
name = 'summary/dfs/04_29_2019__09-51'
df_pairs = pd.read_pickle(name)
df_pairs
# Out:
#     Leg1  Leg2  t_statistic   p_value  zero_cross  half_life  hurst_exponent  \
# 0    BAL  CORN    -2.908874  0.044326          61         47        0.360220
# 1    BAL  SOYB    -3.626185  0.005280          35         28        0.339315
# 2    GSC   UGA    -3.664341  0.004644          92         22        0.359646
# 3    IEZ   PXI    -3.019596  0.033104          53         39        0.420533
# 4    DBE   USL    -2.916692  0.043441          60         57        0.493977
# 5    DBE   UGA    -3.502738  0.007917          64         31        0.375788
# 6    PXI   VDE    -2.985720  0.036250          45         38        0.386136
# 7    RJI  SOYB    -3.139419  0.023770          72         26        0.428589
# 8    BNO   UGA    -3.377133  0.011764          68         32        0.384752
# 9    AMJ  AMLP    -3.043482  0.031028          79         16        0.405055
# 10   GSC   USL    -3.474986  0.008653         127         32        0.444217
# ...

# %%
df_pairs.half_life.mean()
# Out:
# 25.9
