# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import pickle

# just set the seed for the random number generator
np.random.seed(107)

# %%
from tiingo import TiingoClient

config = {}

# To reuse the same HTTP Session across API calls (and have better performance), include a session key.
config['session'] = True

# If you don't have your API key as an environment variable,
# pass it in via a configuration dictionary.
config['api_key'] = "fd7689ea0019b4292b78d3efd6f7bb9c896083ff"

# Initialize
client = TiingoClient(config)

# %% [markdown]
# ### Import Classes

# %%
# %load_ext autoreload
# %aimport class_SeriesAnalyser, class_Trader, class_DataProcessor
# %autoreload 1

# %%
data_processor = class_DataProcessor.DataProcessor()

# %% [markdown]
# # Preprocessing ETFs Dataset
#
# We proceed to retrieve the time series from the identified ETFs, and save the data retrieved in a Datframe.
#
# 1. Upload time series corresponding to ETFs and store them in a dictionary
# 2. Convert the dictionary in a Dataframe by concatenating time series
# 3. Interpolate Nan values
# 4. Save Dataframe in pickle file

# %%
etfs, etfs_unique, tickers = data_processor.read_ticker_excel(path='data/etfs/commodity_ETFs_long_updated.xlsx')

# %%
duplicated_etfs = etfs[etfs.duplicated(subset=['Ticker'], keep=False)].sort_values(['Ticker'])
duplicated_etfs
# Out:
#               Sector Ticker  \
# 224             Gold   AAAU
# 335  Precious Metals   AAAU
# 56       Commodities   AAAU
# 359           Silver    AGQ
# 331  Precious Metals    AGQ
# 46       Commodities    AGQ
# 141           Cotton    BAL
# 102      Commodities    BAL
# 10       Agriculture    BAL
# 326  Precious Metals    BAR
# 219             Gold    BAR
# 34       Commodities    BAR
# 58       Commodities    BNO
# 291              Oil    BNO
# 80       Commodities   BOIL
# 271      Natural Gas   BOIL
# 8        Agriculture   CANE
# 372            Sugar   CANE
# 98       Commodities   CANE
# 140             Corn   CORN
# 68       Commodities   CORN
# 2        Agriculture   CORN
# 100      Commodities    COW
# 9        Agriculture    COW
# 260        Livestock    COW
# 95       Commodities   CPER
# 139           Copper   CPER
# 193           Energy   CRAK
# 314        Oil & Gas   CRAK
# 35       Commodities    DBA
# ..               ...    ...
# 330  Precious Metals   USLV
# 27       Commodities    USO
# 279              Oil    USO
# 128      Commodities   USOD
# 307              Oil   USOD
# 103      Commodities   USOI
# 304              Oil   USOI
# 81       Commodities   USOU
# 298              Oil   USOU
# 121      Commodities    USV
# 354  Precious Metals    USV
# 366           Silver    USV
# 37       Commodities    UWT
# 281              Oil    UWT
# 3        Agriculture   WEAT
# 379            Wheat   WEAT
# 70       Commodities   WEAT
# 127      Commodities   WTID
# 306              Oil   WTID
# 300              Oil   WTIU
# 88       Commodities   WTIU
# 286              Oil    XES
# 162           Energy    XES
# 147           Energy    XOP
# 278              Oil    XOP
# 178           Energy   YGRN
# 310        Oil & Gas   YGRN
# 363           Silver    ZSL
# 84       Commodities    ZSL
# 342  Precious Metals    ZSL
#
#                                            Description  \
# 224                       Perth Mint Physical Gold ETF
# 335                       Perth Mint Physical Gold ETF
# 56                        Perth Mint Physical Gold ETF
# 359                             ProShares Ultra Silver
# 331                             ProShares Ultra Silver
# 46                              ProShares Ultra Silver
# 141  iPath Series B Bloomberg Cotton Subindex Total...
# 102  iPath Series B Bloomberg Cotton Subindex Total...
# 10   iPath Series B Bloomberg Cotton Subindex Total...
# 326                           GraniteShares Gold Trust
# 219                           GraniteShares Gold Trust
# 34                            GraniteShares Gold Trust
# 58                     United States Brent Oil Fund LP
# 291                    United States Brent Oil Fund LP
# 80               ProShares Ultra Bloomberg Natural Gas
# 271              ProShares Ultra Bloomberg Natural Gas
# 8                                  Teucrium Sugar Fund
# 372                                Teucrium Sugar Fund
# 98                                 Teucrium Sugar Fund
# 140                                 Teucrium Corn Fund
# 68                                  Teucrium Corn Fund
# 2                                   Teucrium Corn Fund
# 100  iPath Series B Bloomberg Livestock Subindex To...
# 9    iPath Series B Bloomberg Livestock Subindex To...
# 260  iPath Series B Bloomberg Livestock Subindex To...
# 95                     United States Copper Index Fund
# 139                    United States Copper Index Fund
# 193                    VanEck Vectors Oil Refiners ETF
# 314                    VanEck Vectors Oil Refiners ETF
# 35                         Invesco DB Agriculture Fund
# ..                                                 ...
# 330                  VelocityShares 3X Long Silver ETN
# 27                           United States Oil Fund LP
# 279                          United States Oil Fund LP
# 128                    United States 3x Short Oil Fund
# 307                    United States 3x Short Oil Fund
# 103  Credit Suisse X-Links Crude Oil Shares Covered...
# 304  Credit Suisse X-Links Crude Oil Shares Covered...
# 81                           United States 3x Oil Fund
# 298                          United States 3x Oil Fund
# 121  ETRACS UBS Bloomberg CMCI Silver Total Return ETN
# 354  ETRACS UBS Bloomberg CMCI Silver Total Return ETN
# 366  ETRACS UBS Bloomberg CMCI Silver Total Return ETN
# 37                VelocityShares 3x Long Crude Oil ETN
# 281               VelocityShares 3x Long Crude Oil ETN
# 3                                  Teucrium Wheat Fund
# 379                                Teucrium Wheat Fund
# 70                                 Teucrium Wheat Fund
# 127  UBS ETRACS - ProShares Daily 3x Inverse Crude ETN
# 306  UBS ETRACS - ProShares Daily 3x Inverse Crude ETN
# 300     UBS ETRACS - ProShares Daily 3x Long Crude ETN
# 88      UBS ETRACS - ProShares Daily 3x Long Crude ETN
# 286        SPDR S&P Oil & Gas Equipment & Services ETF
# 162        SPDR S&P Oil & Gas Equipment & Services ETF
# 147    SPDR S&P Oil & Gas Exploration & Production ETF
# 278    SPDR S&P Oil & Gas Exploration & Production ETF
# 178        MicroSectors U.S. Big Oil Index Inverse ETN
# 310        MicroSectors U.S. Big Oil Index Inverse ETN
# 363                        ProShares UltraShort Silver
# 84                         ProShares UltraShort Silver
# 342                        ProShares UltraShort Silver
#
#                            Issuer       AUM ExpenseRatio 3-MO TR  \
# 224      Exchange Traded Concepts  $105.42M        0.18%     NaN
# 335      Exchange Traded Concepts  $105.42M        0.18%     NaN
# 56       Exchange Traded Concepts  $105.42M        0.18%     NaN
# 359                     ProShares  $172.80M        5.28%     NaN
# 331                     ProShares  $172.80M        5.28%     NaN
# 46                      ProShares  $172.80M        5.28%     NaN
# 141             Barclays Bank PLC    $8.60M        0.45%   3.64%
# 102             Barclays Bank PLC    $8.60M        0.45%   3.64%
# 10              Barclays Bank PLC    $8.60M        0.45%   3.64%
# 326                 GraniteShares  $444.96M        0.17%     NaN
# 219                 GraniteShares  $444.96M        0.17%     NaN
# 34                  GraniteShares  $444.96M        0.17%     NaN
# 58             US Commodity Funds  $102.72M        0.88%  21.29%
# 291            US Commodity Funds  $102.72M        0.88%  21.29%
# 80                      ProShares   $26.58M        1.31%     NaN
# 271                     ProShares   $26.58M        1.31%     NaN
# 8                        Teucrium   $11.16M        3.58%     NaN
# 372                      Teucrium   $11.16M        3.58%     NaN
# 98                       Teucrium   $11.16M        3.58%     NaN
# 140                      Teucrium   $59.24M        3.65%     NaN
# 68                       Teucrium   $59.24M        3.65%     NaN
# 2                        Teucrium   $59.24M        3.65%     NaN
# 100             Barclays Bank PLC    $9.48M        0.45%   3.77%
# 9               Barclays Bank PLC    $9.48M        0.45%   3.77%
# 260             Barclays Bank PLC    $9.48M        0.45%   3.77%
# 95             US Commodity Funds   $14.59M        0.80%   5.00%
# 139            US Commodity Funds   $14.59M        0.80%   5.00%
# 193                        VanEck   $20.42M        0.59%   1.18%
# 314                        VanEck   $20.42M        0.59%   1.18%
# 35                        Invesco  $442.91M        0.89%     NaN
# ..                            ...       ...          ...     ...
# 330                 Credit Suisse  $224.82M        1.65%     NaN
# 27             US Commodity Funds    $1.54B        0.84%  20.27%
# 279            US Commodity Funds    $1.54B        0.84%  20.27%
# 128            US Commodity Funds    $1.97M        1.62%     NaN
# 307            US Commodity Funds    $1.97M        1.62%     NaN
# 103                 Credit Suisse    $8.40M        0.85%  19.85%
# 304                 Credit Suisse    $8.40M        0.85%  19.85%
# 81             US Commodity Funds   $25.75M        1.43%  65.23%
# 298            US Commodity Funds   $25.75M        1.43%  65.23%
# 121                           UBS    $3.73M        0.40%     NaN
# 354                           UBS    $3.73M        0.40%     NaN
# 366                           UBS    $3.73M        0.40%     NaN
# 37                      CitiGroup  $409.40M        1.50%  65.62%
# 281                     CitiGroup  $409.40M        1.50%  65.62%
# 3                        Teucrium   $53.59M        3.63%     NaN
# 379                      Teucrium   $53.59M        3.63%     NaN
# 70                       Teucrium   $53.59M        3.63%     NaN
# 127                           UBS    $2.21M        1.85%     NaN
# 306                           UBS    $2.21M        1.85%     NaN
# 300                           UBS   $19.47M        1.45%  64.51%
# 88                            UBS   $19.47M        1.45%  64.51%
# 286  State Street Global Advisors  $230.49M        0.35%   5.29%
# 162  State Street Global Advisors  $230.49M        0.35%   5.29%
# 147  State Street Global Advisors    $2.34B        0.35%   4.38%
# 278  State Street Global Advisors    $2.34B        0.35%   4.38%
# 178                           BMO   $47.38M        0.95%      --
# 310                           BMO   $47.38M        0.95%      --
# 363                     ProShares   $22.77M        1.62%  11.22%
# 84                      ProShares   $22.77M        1.62%  11.22%
# 342                     ProShares   $22.77M        1.62%  11.22%
#
#                                              Segment
# 224                Commodities: Precious Metals Gold
# 335                Commodities: Precious Metals Gold
# 56                 Commodities: Precious Metals Gold
# 359    Leveraged Commodities: Precious Metals Silver
# 331    Leveraged Commodities: Precious Metals Silver
# 46     Leveraged Commodities: Precious Metals Silver
# 141                  Commodities: Agriculture Cotton
# 102                  Commodities: Agriculture Cotton
# 10                   Commodities: Agriculture Cotton
# 326                Commodities: Precious Metals Gold
# 219                Commodities: Precious Metals Gold
# 34                 Commodities: Precious Metals Gold
# 58                     Commodities: Energy Crude Oil
# 291                    Commodities: Energy Crude Oil
# 80         Leveraged Commodities: Energy Natural Gas
# 271        Leveraged Commodities: Energy Natural Gas
# 8                     Commodities: Agriculture Sugar
# 372                   Commodities: Agriculture Sugar
# 98                    Commodities: Agriculture Sugar
# 140                    Commodities: Agriculture Corn
# 68                     Commodities: Agriculture Corn
# 2                      Commodities: Agriculture Corn
# 100               Commodities: Agriculture Livestock
# 9                 Commodities: Agriculture Livestock
# 260               Commodities: Agriculture Livestock
# 95             Commodities: Industrial Metals Copper
# 139            Commodities: Industrial Metals Copper
# 193                         Equity: Global Oil & Gas
# 314                         Equity: Global Oil & Gas
# 35                          Commodities: Agriculture
# ..                                               ...
# 330    Leveraged Commodities: Precious Metals Silver
# 27                     Commodities: Energy Crude Oil
# 279                    Commodities: Energy Crude Oil
# 128            Inverse Commodities: Energy Crude Oil
# 307            Inverse Commodities: Energy Crude Oil
# 103                    Commodities: Energy Crude Oil
# 304                    Commodities: Energy Crude Oil
# 81           Leveraged Commodities: Energy Crude Oil
# 298          Leveraged Commodities: Energy Crude Oil
# 121              Commodities: Precious Metals Silver
# 354              Commodities: Precious Metals Silver
# 366              Commodities: Precious Metals Silver
# 37           Leveraged Commodities: Energy Crude Oil
# 281          Leveraged Commodities: Energy Crude Oil
# 3                     Commodities: Agriculture Wheat
# 379                   Commodities: Agriculture Wheat
# 70                    Commodities: Agriculture Wheat
# 127            Inverse Commodities: Energy Crude Oil
# 306            Inverse Commodities: Energy Crude Oil
# 300          Leveraged Commodities: Energy Crude Oil
# 88           Leveraged Commodities: Energy Crude Oil
# 286      Equity: U.S. Oil & Gas Equipment & Services
# 162      Equity: U.S. Oil & Gas Equipment & Services
# 147  Equity: U.S. Oil & Gas Exploration & Production
# 278  Equity: U.S. Oil & Gas Exploration & Production
# 178                   Inverse Equity: U.S. Oil & Gas
# 310                   Inverse Equity: U.S. Oil & Gas
# 363      Inverse Commodities: Precious Metals Silver
# 84       Inverse Commodities: Precious Metals Silver
# 342      Inverse Commodities: Precious Metals Silver
#
# [290 rows x 8 columns]

# %%
etfs_unique.Segment.value_counts()
# Out:
# Equity: U.S. MLPs                                            25
# Commodities: Broad Market                                    21
# Commodities: Precious Metals Gold                            12
# Equity: U.S. Energy                                          11
# Commodities: Energy Crude Oil                                 9
# Equity: Global Gold Miners                                    7
# Commodities: Agriculture                                      6
# Inverse Commodities: Energy Crude Oil                         6
# Equity: Global Metals & Mining                                5
# Leveraged Commodities: Energy Crude Oil                       5
# Equity: Global Water                                          5
# Commodities: Precious Metals Silver                           5
# Commodities: Energy                                           4
# Inverse Commodities: Precious Metals Gold                     4
# Commodities: Energy Natural Gas                               3
# Leveraged Equity: Global Gold Miners                          3
# Leveraged Equity: U.S. MLPs                                   3
# Inverse Equity: U.S. Oil & Gas                                3
# Equity: U.S. Oil & Gas Equipment & Services                   3
# Inverse Equity: U.S. Energy                                   3
# Equity: Global Silver Miners                                  3
# Leveraged Commodities: Precious Metals Gold                   3
# Commodities: Precious Metals Platinum                         3
# Inverse Equity: Global Gold Miners                            3
# Commodities: Precious Metals                                  3
# Equity: U.S. Oil & Gas Exploration & Production               3
# Commodities: Agriculture Grains                               3
# Leveraged Commodities: Energy Natural Gas                     2
# Leveraged Equity: U.S. Energy                                 2
# Inverse Commodities: Precious Metals Silver                   2
#                                                              ..
# Inverse Commodities: Energy Natural Gas                       2
# Leveraged Commodities: Precious Metals Silver                 2
# Leveraged Equity: U.S. Oil & Gas                              2
# Commodities: Agriculture Wheat                                1
# Equity: U.S. Oil & Gas                                        1
# Inverse Equity: U.S. Natural Gas                              1
# Commodities: Agriculture Cocoa                                1
# Leveraged Equity: U.S. Natural Gas                            1
# Inverse Equity: U.S. Oil & Gas Exploration & Production       1
# Commodities: Agriculture Cotton                               1
# Commodities: Broad Market Metals                              1
# Commodities: Agriculture Soybeans                             1
# Commodities: Industrial Metals Nickel                         1
# Commodities: Agriculture Livestock                            1
# Equity: Global Oil & Gas Exploration & Production             1
# Commodities: Agriculture Coffee                               1
# Commodities: Industrial Metals Tin                            1
# Commodities: Agriculture Corn                                 1
# Commodities: Industrial Metals Lead                           1
# Equity: Global Energy                                         1
# Equity: U.S. Natural Gas                                      1
# Equity: Global Oil & Gas Equipment & Services                 1
# Commodities: Precious Metals Palladium                        1
# Commodities: Industrial Metals Aluminum                       1
# Equity: Global Coal                                           1
# Leveraged Equity: U.S. Oil & Gas Exploration & Production     1
# Equity: China Energy                                          1
# Commodities: Energy Gasoline                                  1
# Commodities: Agriculture Softs                                1
# Equity: U.S. Metals & Mining                                  1
# Name: Segment, Length: 65, dtype: int64

# %%
print('There are a total of {} segments'.format(len(etfs_unique.Segment.value_counts())))
# Out:
# There are a total of 65 segments

# %% [markdown]
# **Save a dictionary with ticker and corresponding segment**

# %%
ticker_segment_dict = pd.Series(etfs_unique.Segment.values,index=etfs_unique.Ticker).to_dict()
with open('data/etfs/pickle/ticker_segment_dict.pickle', 'wb') as handle:
    pickle.dump(ticker_segment_dict, handle)

# %% [markdown]
# As for downloading the data, we define a wide interval, from 2000 to 2019. Those ETFs not trading during the entire interval will automatically fill with np.Nan the non-trading days.

# %% [markdown]
# **1) Download prices**
#
# *ALERT: DO NOT RUN, UPLOAD PICKLE FILE*

# %%
tickers = list(tickers)
frequency = 'daily'

# %%
error_counter = 0
dataset_tiingo = {key: None for key in tickers}
for ticker in tickers:
    try:
        df = client.get_dataframe([ticker],
                                  frequency=frequency,
                                  metric_name='adjClose',
                                  startDate='2000-01-01',
                                  endDate='2019-01-01')
        series = df[ticker]
        series.name = ticker  # filter close price only
        dataset_tiingo[ticker] = series.copy()
    except:
        error_counter = error_counter + 1
        print('Not Possible to retrieve information for ' + ticker)

print('\nUnable to download ' + str(error_counter / len(tickers) * 100) + '% of the ETFs')

df_prices, _ = data_processor.dict_to_df(dataset_tiingo)

# We try to fill sporadic null values. For this purpose we can use either the `interpolate` or the
# `fillna` function.
# src: https://datascience.stackexchange.com/questions/25924/difference-between-interpolate-and-fillna-in-pandas.
# Using the limit parameter, we can set the maximum number of consecutive NaNs to fill.

limit = 5
df_prices_interpolate = df_prices.interpolate(method="linear",limit=limit)
df_prices_interpolate.to_pickle('data/etfs/pickle/commodity_ETFs_interpolated.pickle')
# Out:
# Not Possible to retrieve information for NRGD
# Not Possible to retrieve information for NRGO
# Not Possible to retrieve information for NRGU
# Not Possible to retrieve information for NRGZ
# Not Possible to retrieve information for YGRN
#
# Unable to download 2.3474178403755865% of the ETFs

# %% [markdown]
# **2) Download volume data**
#
# *ALERT: DO NOT RUN, UPLOAD PICKLE FILE*

# %%
# get info about volume
frequency = 'daily'
error_counter = 0
dataset_tiingo_volume = {key: None for key in tickers}
for ticker in tickers:
    try:
        df = client.get_dataframe([ticker],
                                  frequency=frequency,
                                  metric_name='volume',
                                  startDate='2000-01-01',
                                  endDate='2019-01-01')
        series = df[ticker]
        series.name = ticker  # filter close price only
        dataset_tiingo_volume[ticker] = series.copy()
    except:
        error_counter = error_counter + 1
        print('Not Possible to retrieve information for ' + ticker)

print('\nUnable to download info about volume from ' + str(error_counter / len(tickers) * 100) + '% of the ETFs')

df_volume, _ = data_processor.dict_to_df(dataset_tiingo_volume)

# interpolate
limit = 5
df_volume = df_volume.interpolate(method="linear",limit=limit)
df_volume.to_pickle('data/etfs/pickle/commodity_ETFs_volume.pickle')
# Out:
# Not Possible to retrieve information for NRGD
# Not Possible to retrieve information for NRGO
# Not Possible to retrieve information for NRGU
# Not Possible to retrieve information for NRGZ
# Not Possible to retrieve information for YGRN
#
# Unable to download info about volume from 2.3474178403755865% of the ETFs

# %% [markdown]
# # Data cleaning - starts here
#
# **Define dates**

# %%
initial_train_date = '01-01-2009'
final_train_date = '31-12-2017'
initial_test_date = '01-01-2018'
final_test_date = '31-12-2018'

# %% [markdown]
# **3)Filter ETFs with at least one day of no trading**

# %%
# in case you need to read the previously saved df
df_volume = pd.read_pickle('data/etfs/pickle/commodity_ETFs_volume')#.pickle

# split data in training and test
df_volume_train, df_volume_test = data_processor.split_data(df_volume,
                                                            (initial_train_date,
                                                             final_train_date),
                                                            (initial_test_date,
                                                             final_test_date),
                                                            remove_nan=True)

# interpolate for single day ocurrences
df_volume_train = df_volume_train.replace(to_replace=0,value=np.nan)
df_volume_train = df_volume_train.interpolate(method="linear",limit=2)
# replace again by zeros
df_volume_train = df_volume_train.replace(to_replace=np.nan,value=0)

non_zeros_counts = df_volume_train.fillna(0).astype(bool).sum(axis=0)
zero_counts = pd.Series([len(df_volume_train)]*len(non_zeros_counts), index=non_zeros_counts.index) -\
              non_zeros_counts
zero_counts = zero_counts[zero_counts != 0]
    
print('Must remove {} tickers because of insufficient liquidity'.format(len(zero_counts)))
tickers_to_remove_2009 = list(zero_counts.index)

# filter prices 
df_prices_interday = pd.read_pickle('data/etfs/pickle/commodity_ETFs_interpolated')#.pickle')
df_prices_interday_screened = df_prices_interday.drop(columns=tickers_to_remove_2009)
df_prices_interday_screened.to_pickle('data/etfs/pickle/commodity_ETFs_interpolated_screened.pickle')
# Out:
# Total of 208 tickers
# Total of 71 tickers after removing tickers with Nan values
# Must remove 12 tickers because of insufficient liquidity

# %% [markdown]
# **4) Analyzing data set feasibiity**

# %%
# in case you need to read the previously saved df
df_prices_interday = pd.read_pickle('data/etfs/pickle/commodity_ETFs_interpolated_screened.pickle')

# %%
# split data in training and test
df_prices_train, df_prices_test = data_processor.split_data(df_prices_interday,
                                                            (initial_train_date,
                                                             final_train_date),
                                                            (initial_test_date,
                                                             final_test_date),
                                                            remove_nan=True)
print('Total days of trading: ', len(df_prices_train)+len(df_prices_test))
# Out:
# Total of 196 tickers
# Total of 59 tickers after removing tickers with Nan values
# Total days of trading:  2516

# %% [markdown]
# Naturally, only ETFs available to trade at the present time can be obtained.

# %% [markdown]
# **5) List of ETFs**

# %%
etfs_list = list(df_prices_train.columns)
with open('data/etfs/ETFs.txt', 'w') as f:
    for item in etfs_list:
        f.write("%s\n" % item)

# %% [markdown]
# # Intraday data

# %%
len(tickers_to_remove_2009)
# Out:
# 12

# %%
df_prices = pd.read_excel('data/etfs/intraday_etfs.xlsx')
df_prices.index = pd.to_datetime(df_prices.index)

# interpolate
limit = 5
df_prices_interpolate = df_prices.interpolate(method="linear",limit=limit)

# screen iliquid ETFs
df_prices_screened = df_prices_interpolate.drop(columns=tickers_to_remove_2009)
df_prices_screened.to_pickle('data/etfs/pickle/commodity_ETFs_intraday_interpolated_screened.pickle')

# %%
df_prices_screened.tail(3)
# Out:
#                         AGQ     CGW     DBA    DBB   DBC    DBE    DBO    DBP  \
# 2018-12-31 20:50:00  26.447  31.080  16.930  15.38  14.5  12.45  8.474  36.35
# 2018-12-31 20:55:00  26.410  31.078  16.930  15.37  14.5  12.45  8.470  36.35
# 2018-12-31 21:00:00  26.370  31.140  16.945  15.39  14.5  12.41  8.460  36.35
#
#                         DBS    DGL   ...      UGA     UGL     UNG    USL  \
# 2018-12-31 20:50:00  22.982  39.51   ...    22.92  37.375  24.690  17.97
# 2018-12-31 20:55:00  22.982  39.51   ...    22.95  37.380  24.695  17.97
# 2018-12-31 21:00:00  22.980  39.51   ...    22.95  37.400  24.710  17.95
#
#                        USO     VDE   XES    XLE     XME     XOP
# 2018-12-31 20:50:00  9.674  76.846  8.96  57.13  26.140  26.445
# 2018-12-31 20:55:00  9.670  76.670  8.94  56.99  26.065  26.375
# 2018-12-31 21:00:00  9.670  77.090  9.00  57.35  26.190  26.530
#
# [3 rows x 59 columns]

# %% [markdown]
# **Remove outliers by hand**

# %%
def outliers(df_real):
    df = df_real.copy()
    
    outliers = []
    for ticker in df.columns:
        outliers_idx = df[ticker][np.abs(df[ticker].pct_change()) > 0.5].index
        if len(outliers_idx)>0:
            outliers.append((ticker, outliers_idx))
        #df[ticker][outliers_idx] = np.nan
        #limit = 2
        #df[ticker] = df[ticker].fillna(method='ffill', limit=limit)
        
    #df = data_processor.remove_tickers_with_nan(df, 0)
        
    return outliers

# %%
price_outliers = outliers(df_prices_screened)

# %% [markdown]
# Correct:

# %%
price_outliers
# Out:
# [('NLR',
#   DatetimeIndex(['2013-07-01 13:35:00', '2013-07-01 13:55:00'], dtype='datetime64[ns]', freq=None)),
#  ('PXI', DatetimeIndex(['2010-05-06 18:50:00', '2010-05-06 19:00:00',
#                  '2010-05-06 19:05:00'],
#                 dtype='datetime64[ns]', freq=None)),
#  ('RYE',
#   DatetimeIndex(['2010-05-06 18:55:00', '2010-05-06 19:00:00'], dtype='datetime64[ns]', freq=None))]

# %%
# detected using function above
df_prices_screened['NLR']['2013-07-01 13:35:00':'2013-07-01 13:50:00']= 35.881
df_prices_screened['PXI']['2010-05-06 18:50:00':'2010-05-06 19:00:00']= 24.75800
df_prices_screened['RYE']['2010-05-06 18:55:00']=40.808
# detected by analyzing pair results
#df_prices_screened['FXN']['2010-05-06 19:00:00']=15.589
#df_prices_screened['IYE']['2010-05-06 18:55:00']=26.684
#df_prices_screened['GLL']['2009-01-23 17:50:00':'2009-01-23 18:00:00']=359.00
df_prices_screened.to_pickle('data/etfs/pickle/commodity_ETFs_intraday_interpolated_screened_no_outliers.pickle')

# %% [markdown]
# # 2014-2017

# %% [markdown]
# Dates

# %%
initial_train_date = '01-01-2014'
final_train_date = '31-12-2016'
initial_test_date = '01-01-2017'
final_test_date = '31-12-2017'

# %% [markdown]
# Prices

# %%
# READ FROM 2009
df_prices_from_2009 = pd.read_excel('data/etfs/intraday_etfs.xlsx')
df_prices_from_2009 = df_prices_from_2009.rename(columns={'Unnamed: 0':'Date'}).set_index('Date')

# interpolate
limit = 5
df_prices_from_2009 = df_prices_from_2009.interpolate(method="linear",limit=limit)

# screen iliquid ETFs
df_prices_from_2009 = df_prices_from_2009.drop(columns=tickers_to_remove_2009)

# %%
df_prices_from_2014 = pd.read_excel('data/etfs/intraday_etfs_2014_2019.xlsx')
df_prices_from_2014 = df_prices_from_2014[:len(df_prices_from_2014)-2]# remove trash
df_prices_from_2014 = df_prices_from_2014.rename(columns={'Unnamed: 0':'Date'})
df_prices_from_2014= df_prices_from_2014.set_index('Date')

# interpolate
limit = 5
df_prices_interpolate_2014 = df_prices_from_2014.interpolate(method="linear",limit=limit)

# %%
df_prices_from_2014_complete = pd.concat([df_prices_from_2009['2012-01-01':], df_prices_from_2014], axis=1)

# %%
df_prices_from_2014_complete.to_pickle('data/etfs/pickle/commodity_ETFs_from_2014_complete.pickle')

# %%
def outliers(df_real):
    df = df_real.copy()
    
    outliers = []
    for ticker in df.columns:
        outliers_idx = df[ticker][np.abs(df[ticker].pct_change()) > 0.5].index
        if len(outliers_idx)>0:
            outliers.append((ticker, outliers_idx))
        #df[ticker][outliers_idx] = np.nan
        #limit = 2
        #df[ticker] = df[ticker].fillna(method='ffill', limit=limit)
        
    #df = data_processor.remove_tickers_with_nan(df, 0)
        
    return outliers

df_prices_from_2014_complete = pd.read_pickle('data/etfs/pickle/commodity_ETFs_from_2014_complete.pickle')
outliers_from_2014 = outliers(df_prices_from_2014_complete)

# %%
outliers_from_2014
df_prices_from_2014_complete['NLR']['2013-07-01 13:35:00':'2013-07-01 13:50:00']= 35.881
df_prices_from_2014_complete['FTGC']['2014-02-24 14:35:00':'2014-02-24 14:40:00']=33.011
df_prices_from_2014_complete['MLPG']['2013-08-07 13:35:00']=32.494
df_prices_from_2014_complete = df_prices_from_2014_complete.drop(columns=['DGAZ', 'UGLD', 'USLV'], axis=1)
df_prices_from_2014_complete.to_pickle('data/etfs/pickle/commodity_ETFs_from_2014_complete.pickle')

# %% [markdown]
# # WARNING: No need to run again, used to generate prices from 2014

# %% [markdown]
# Tickers to remove

# %%
# in case you need to read the previously saved df
df_volume = pd.read_pickle('data/etfs/pickle/commodity_ETFs_volume')#.pickle

# split data in training and test
df_volume_train, df_volume_test = data_processor.split_data(df_volume,
                                                            (initial_train_date,
                                                             final_train_date),
                                                            (initial_test_date,
                                                             final_test_date),
                                                             remove_nan=True)

# interpolate for single day ocurrences
df_volume_train = df_volume_train.replace(to_replace=0,value=np.nan)
df_volume_train = df_volume_train.interpolate(method="linear",limit=2)
# replace again by zeros
df_volume_train = df_volume_train.replace(to_replace=np.nan,value=0)

non_zeros_counts = df_volume_train.fillna(0).astype(bool).sum(axis=0)
zero_counts = pd.Series([len(df_volume_train)]*len(non_zeros_counts), index=non_zeros_counts.index) -\
              non_zeros_counts
zero_counts = zero_counts[zero_counts != 0]
    
print('Must remove {} tickers because of insufficient liquidity'.format(len(zero_counts)))
tickers_to_remove_2014 = list(zero_counts.index)
# Out:
# Total of 208 tickers
# Total of 135 tickers after removing tickers with Nan values
# Must remove 16 tickers because of insufficient liquidity

# %%
etfs_list = [ticker for ticker in df_volume_train.columns if ticker not in tickers_to_remove_2014]

df_2009 = pd.read_pickle('data/etfs/pickle/commodity_ETFs_intraday_interpolated_screened_no_outliers.pickle')
tickers_from_2009 = df_2009.columns
etfs_list = [ticker for ticker in etfs_list if ticker not in tickers_from_2009]
with open('data/etfs/ETFs_2014_2019.txt', 'w') as f:
    for item in etfs_list:
        f.write("%s\n" % item)
