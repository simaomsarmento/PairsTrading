# %% [markdown]
# # A Pairs Trading strategy boosted with AI
#
# This notebook explores a pairs trading strategy fueled by AI innovative techniques. This projected is being developed as part of a master thesis for the degree of Electrical and Computer Engineering.

# %% [markdown]
# ## Dependencies
#
# This notebook requires code from:
#
# - `class_SeriesAnalyser.py` - contains a set of functions to deal with time series analysis.
# - `class_Trader.py` - contains a set of functions concerning trading strategies.
# - `class_DataProcessor.py` - contains a set of functions concerning the data pre processing.
#
# As a good practise, the notebook solely intends to exemplify the application of different trading strategies for different dataset examples, rather than coding the strategies theirselves. Please look into the files menitoned above for more detailed info on how the functions are built.

# %% [markdown]
# ## Table of Contents
#
#     1. Commodity ETFs - entire workflow application example

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

import json

import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller

import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Import Datetime and the Pandas DataReader
from datetime import datetime
from pandas_datareader import data, wb

# Import alpha vantage
from alpha_vantage.timeseries import TimeSeries

# Import scikit instruments
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing
from sklearn.metrics import silhouette_score

# just set the seed for the random number generator
np.random.seed(107)
# Out:
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
config_file = 'config/config_commodities_2013_2019.json'

# %% [markdown]
# ### Import Configurations

# %%
with open(config_file, 'r') as f:
    config = json.load(f)

# %% [markdown]
# ### Import Classes

# %%
# %load_ext autoreload
# %aimport class_SeriesAnalyser, class_Trader, class_DataProcessor
# %autoreload 1

# %%
series_analyser = class_SeriesAnalyser.SeriesAnalyser()
trader = class_Trader.Trader()
data_processor = class_DataProcessor.DataProcessor()

# %% [markdown]
# # 1. Commodity ETFs Dataset
#
# In this section, we proceed to analyze ETFs from different commodity sectors and detect possible interesting pairs. The process goes as follows:
#
# - Upload time series corresponding to ETFs
# - Apply dimensionality reduction and cluster securities
# - Run cointegration tests for securities within the same cluster

# %% [markdown]
# We start by retrieving the data from a Dataframe saved in a pickle file, as it was previously processed in the `PairsTrading_CommodityETFS_Datapreprocessing.ipynb` notebook.

# %%
df_prices = pd.read_pickle('data/etfs/pickle/commodity_ETFs_long_updated')

# %%
# split data in training and test
df_prices_train, df_prices_test = data_processor.split_data(df_prices,
                                                            (config['dataset']['training_initial_date'],
                                                             config['dataset']['training_final_date']),
                                                            (config['dataset']['testing_initial_date'],
                                                             config['dataset']['testing_final_date']),
                                                            remove_nan=True)
# Out:
# Total of 208 tickers
# Total of 125 tickers after removing tickers with Nan values

# %% [markdown]
# ## PCA on returns
#
# A purely fundamental approach is a one way to search for pairs, however breadth will likely be low. Sharpe can be maximized by having high breadth (high number of bets). With N stocks in the universe, there are N*(N-1)/2 pair-wise relationships. However, if we do a brute-force search over these, we will likely end up with many spurious results due to comparison bias. As such, we narrow down the search space in a reasonable way, assuming ETFs that share loadings to common factors (defined below) in the past should be related in the future.

# %% [markdown]
# **Obtain returns**

# %%
df_returns = data_processor.get_return_series(df_prices_train)
df_returns.head()
# Out:
#                  AGQ       AMJ      AMLP       AMU       BCM       BNO  \
# 2013-02-05  0.005868 -0.005783 -0.000579 -0.003674  0.000840  0.008831
# 2013-02-06  0.000208 -0.002094 -0.005211 -0.003319 -0.001767  0.003225
# 2013-02-07 -0.021662 -0.001632  0.001222  0.006659 -0.004355  0.003330
# 2013-02-08 -0.000639 -0.000467  0.003542  0.004410  0.005483  0.011672
# 2013-02-11 -0.030422  0.012150  0.003529 -0.004757  0.000000 -0.004298
#
#                 BOIL      CANE       CGW      CHIE    ...          USO  \
# 2013-02-05  0.055689 -0.009837  0.009939  0.001328    ...     0.007188
# 2013-02-06  0.017163  0.000000  0.002995  0.006594    ...     0.000285
# 2013-02-07 -0.082878 -0.018786 -0.003840 -0.009180    ...    -0.010274
# 2013-02-08 -0.018669  0.003584  0.002998  0.001774    ...     0.000577
# 2013-02-11  0.011304  0.000000 -0.000854  0.000211    ...     0.012104
#
#                  USV       VDE      WEAT       XES       XLE       XME  \
# 2013-02-05  0.002477  0.008148 -0.003414  0.009032  0.008664 -0.004330
# 2013-02-06  0.000225  0.000449 -0.003377 -0.000767  0.000641  0.019684
# 2013-02-07 -0.010779 -0.002603 -0.010726  0.009726 -0.002562 -0.005387
# 2013-02-08  0.008627  0.008910  0.005214  0.015209  0.009377  0.002031
# 2013-02-11 -0.025433 -0.005977 -0.020872 -0.015730 -0.004963 -0.000225
#
#                  XOP      YMLP       ZSL
# 2013-02-05  0.019314 -0.001048 -0.007127
# 2013-02-06  0.006260 -0.003148 -0.001570
# 2013-02-07 -0.005548 -0.005263  0.022804
# 2013-02-08  0.012172 -0.000529  0.000110
# 2013-02-11 -0.009020  0.000529  0.030222
#
# [5 rows x 125 columns]

# %%
print('Total number of possible pairs: ', len(df_returns.columns)*(len(df_returns.columns)-1)/2)
# Out:
# Total number of possible pairs:  7750.0

# %% [markdown]
# **Applying PCA on Returns**
#
# - Protecting from `Curse of Dimensionality` - *source: https://stats.stackexchange.com/questions/232500/how-do-i-know-my-k-means-clustering-algorithm-is-suffering-from-the-curse-of-dim*: Perform a principle components analysis (PCA) and look at how the eigenvalues drop off. It is quite common that most of the variation exists in a couple of dimensions (which typically cut across the original dimensions of your dataset)

# %% [markdown]
# To analyze how many principal components we should be using, and accounting for the fact that too many features might incur curse of dimensionality, we proceed to visualize the explanatory power of the first 20 features. We observe that most of the information is in fact contained within the first features. We choose to keep the first 14.

# %%
# this show us the feature importance of the 
N_PRIN_COMPONENTS = 20
_, explained_variance = series_analyser.apply_PCA(N_PRIN_COMPONENTS, df_returns)
print(explained_variance)
# Out:
# [0.03376332 0.01965136 0.01347947 0.00369018 0.00253426 0.00123334
#  0.00116289 0.00096824 0.00073446 0.00067742 0.00060487 0.00050789
#  0.00038122 0.00030468 0.00029919 0.00028597 0.0002763  0.00024384
#  0.0002311  0.00021265]

# %%
N_PRIN_COMPONENTS = 15#config['PCA']['N_COMPONENTS']
X, explained_variance = series_analyser.apply_PCA(N_PRIN_COMPONENTS, df_returns)

# %% [markdown]
# **Clustering**
#
# We will make use of the DBSCAN unsupervised clustering algorithm, which is available in scikit-learn. DBSCAN has advantages in this use case, specifically:
#
# - DBSCAN does not cluster all stocks; it leaves out stocks which do not neatly fit into a cluster;
# - No need to specify the number of clusters.
#
# The clustering algorithm will give us sensible candidate pairs. We will need to do some validation in the next step.

# %%
clustered_series_all, clustered_series, counts, clf = series_analyser.apply_DBSCAN(config['clustering']['epsilon'],
                                                                                   config['clustering']['min_samples'],
                                                                                   X,
                                                                                   df_returns)
# Out:
# Clusters discovered: 13
# Pairs to evaluate: 27

# %% [markdown]
# The epsilon parameter strongly dependens on the data. Because of the that, it is not obvious wether DBSCAN is the best algo.

# %%
print(counts)
# Out:
# 5     4
# 0     4
# 12    3
# 4     3
# 11    2
# 10    2
# 9     2
# 8     2
# 7     2
# 6     2
# 3     2
# 2     2
# 1     2
# dtype: int64

# %% [markdown]
# ### Optimize according to Silhouette
#
# When performing PCA, use number of components that maximizes the silhouette coefficient after clustering.

# %%
X, clustered_series_all, clustered_series, counts, clf = series_analyser.clustering_for_optimal_PCA(10,
                                                                                  20,
                                                                                  df_returns,
                                                                                  config['clustering'])
# Out:
# Number of components:  10
# Returns shape:  (985, 125)
# Clusters discovered: 14
# Pairs to evaluate: 129
# Silhouette score  0.04865672290701552
#
# Number of components:  11
# Returns shape:  (985, 125)
# Clusters discovered: 13
# Pairs to evaluate: 109
# Silhouette score  0.006385280607143361
#
# Number of components:  12
# Returns shape:  (985, 125)
# Clusters discovered: 14
# Pairs to evaluate: 82
# Silhouette score  -0.049337019194811524
#
# Number of components:  13
# Returns shape:  (985, 125)
# Clusters discovered: 14
# Pairs to evaluate: 58
# Silhouette score  -0.09185078175020059
#
# Number of components:  14
# Returns shape:  (985, 125)
# Clusters discovered: 14
# Pairs to evaluate: 48
# Silhouette score  -0.12899343030758717
#
# Number of components:  15
# Returns shape:  (985, 125)
# Clusters discovered: 13
# Pairs to evaluate: 24
# Silhouette score  -0.2053487028367739
#
# Number of components:  16
# Returns shape:  (985, 125)
# Clusters discovered: 11
# Pairs to evaluate: 22
# Silhouette score  -0.22924702876369965
#
# Number of components:  17
# Returns shape:  (985, 125)
# Clusters discovered: 8
# Pairs to evaluate: 16
# Silhouette score  -0.27309398290219905
#
# Number of components:  18
# Returns shape:  (985, 125)
# Clusters discovered: 7
# Pairs to evaluate: 13
# Silhouette score  -0.2928918039643688
#
# Number of components:  19
# Returns shape:  (985, 125)
# Clusters discovered: 7
# Pairs to evaluate: 15
# Silhouette score  -0.271275998904021
#
# The best silhouette coefficient was: 0.04865672290701552 for 10 principal components

# %% [markdown]
# **Fundamental analysis for clusters**

# %%
etfs, etfs_unique, tickers = \
            data_processor.read_ticker_excel(path='data/etfs/commodity_ETFs_long_updated.xlsx')

# %%
for label_n in range(len(counts)):
    elements_cluster_n = list(clustered_series[clustered_series == label_n].index)
    etfs_cluster_n = etfs_unique[etfs_unique['Ticker'].isin(elements_cluster_n)]
    print('\nCluster {}:\n{}'.format(label_n, etfs_cluster_n[['Ticker', 'Segment']]))
# Out:
# Cluster 0:
#     Ticker            Segment
# 145    AMJ  Equity: U.S. MLPs
# 143   AMLP  Equity: U.S. MLPs
# 160    AMU  Equity: U.S. MLPs
# 183   IMLP  Equity: U.S. MLPs
# 150   MLPA  Equity: U.S. MLPs
# 200   MLPG  Equity: U.S. MLPs
# 148   MLPI  Equity: U.S. MLPs
# 209   MLPY  Equity: U.S. MLPs
#
# Cluster 1:
#     Ticker                    Segment
# 69     BCM  Commodities: Broad Market
# 26     DBC  Commodities: Broad Market
# 77    DJCI  Commodities: Broad Market
# 30     DJP  Commodities: Broad Market
# 53     GCC  Commodities: Broad Market
# 134    RJI  Commodities: Broad Market
# 65     UCI  Commodities: Broad Market
# 36    USCI  Commodities: Broad Market
#
# Cluster 2:
#     Ticker                        Segment
# 58     BNO  Commodities: Energy Crude Oil
# 61     DBE            Commodities: Energy
# 41     DBO  Commodities: Energy Crude Oil
# 135    RJN            Commodities: Energy
# 72     UGA   Commodities: Energy Gasoline
# 66     USL  Commodities: Energy Crude Oil
# 27     USO  Commodities: Energy Crude Oil
#
# Cluster 3:
#     Ticker               Segment
# 375    CGW  Equity: Global Water
# 376    FIW  Equity: Global Water
# 374    PHO  Equity: Global Water
# 377    PIO  Equity: Global Water
#
# Cluster 4:
#    Ticker                              Segment
# 96    DBS  Commodities: Precious Metals Silver
# 40   SIVR  Commodities: Precious Metals Silver
# 24    SLV  Commodities: Precious Metals Silver
#
# Cluster 5:
#     Ticker                            Segment
# 59     DGL  Commodities: Precious Metals Gold
# 22     GLD  Commodities: Precious Metals Gold
# 76    GLDI  Commodities: Precious Metals Gold
# 23     IAU  Commodities: Precious Metals Gold
# 29    SGOL  Commodities: Precious Metals Gold
# 107    UBG  Commodities: Precious Metals Gold
#
# Cluster 6:
#    Ticker                                      Segment
# 62    DGP  Leveraged Commodities: Precious Metals Gold
# 64    UGL  Leveraged Commodities: Precious Metals Gold
#
# Cluster 7:
#    Ticker                                    Segment
# 90    DZZ  Inverse Commodities: Precious Metals Gold
# 85    GLL  Inverse Commodities: Precious Metals Gold
#
# Cluster 8:
#    Ticker                   Segment
# 13    FUD  Commodities: Agriculture
# 14    UAG  Commodities: Agriculture
#
# Cluster 9:
#     Ticker                                          Segment
# 164    FXN                              Equity: U.S. Energy
# 159    IEO  Equity: U.S. Oil & Gas Exploration & Production
# 182    PXE  Equity: U.S. Oil & Gas Exploration & Production
# 175    PXI                              Equity: U.S. Energy
# 163    RYE                              Equity: U.S. Energy
#
# Cluster 10:
#     Ticker                     Segment
# 213    GDX  Equity: Global Gold Miners
# 232   GOEX  Equity: Global Gold Miners
# 220   RING  Equity: Global Gold Miners
#
# Cluster 11:
#     Ticker                    Segment
# 137    GSC  Commodities: Broad Market
# 28     GSG  Commodities: Broad Market
# 75     GSP  Commodities: Broad Market
#
# Cluster 12:
#     Ticker                                        Segment
# 165    IEZ    Equity: U.S. Oil & Gas Equipment & Services
# 152    OIH  Equity: Global Oil & Gas Equipment & Services
# 195    PXJ    Equity: U.S. Oil & Gas Equipment & Services
# 162    XES    Equity: U.S. Oil & Gas Equipment & Services
#
# Cluster 13:
#     Ticker              Segment
# 153    IYE  Equity: U.S. Energy
# 144    VDE  Equity: U.S. Energy
# 142    XLE  Equity: U.S. Energy

# %% [markdown]
# **Visualizing with t-sne**

# %%
def plot_TSNE(X, clf, clustered_series_all):
    """
    This function makes use of t-sne to visualize clusters in 2d.
    """
    X_tsne = TSNE(learning_rate=1000, perplexity=25, random_state=1337).fit_transform(X) 
    
    # visualization
    plt.figure(1, facecolor='white', figsize=(15,5))
    plt.clf()
    plt.axis('off')

    labels = clf.labels_
    plt.scatter(
        X_tsne[(labels!=-1), 0],
        X_tsne[(labels!=-1), 1],
        s=100,
        alpha=0.85,
        c=labels[labels!=-1],
        cmap=cm.Paired
    )

    plt.scatter(
        X_tsne[(clustered_series_all==-1).values, 0],
        X_tsne[(clustered_series_all==-1).values, 1],
        s=100,
        alpha=0.10
    )

    plt.title('T-SNE of all ETFs with DBSCAN Clusters Noted');

# %%
plot_TSNE(X,clf, clustered_series_all)

# %% [markdown]
# What can we conclude??
# - First of all, the securities in each cluster are indeed from segments tham seem to be fundamentally related.
# - Moreover, we see that some filtering is being performed, and the clustering goes further than a simple groupby segment would.
#
# Let's proceed to plot the identified time series.

# %%
for clust in range(len(counts)):
    symbols = list(clustered_series[clustered_series==clust].index)
    means = np.log(df_prices_train[symbols].mean())
    series = np.log(df_prices_train[symbols]).sub(means)
    series.plot(title='Stock Time Series for Cluster %d' % clust, figsize=(10,5))

# %% [markdown]
# We now investigate whether it is possible to find cointegrated pairs within the clusters

# %%
pairs, unique_tickers = series_analyser.get_candidate_pairs(clustered_series=clustered_series,
                                                            pricing_df_train=df_prices_train,
                                                            pricing_df_test=df_prices_test,
                                                            n_clusters=len(counts),
                                                            min_half_life=config['pair_restrictions']['min_half_life'],
                                                            min_zero_crosings=config['pair_restrictions']['min_zero_crossings'],
                                                            p_value_threshold=config['pair_restrictions']['p_value_threshold'],
                                                            hurst_threshold=config['pair_restrictions']['hurst_threshold']
                                                            )
# Out:
# Found 23 pairs
# The pairs contain 28 unique tickers

# %%
lookback_multiplier= config['trading']['lookback_multiplier']
entry_multiplier= config['trading']['entry_multiplier']
exit_multiplier= config['trading']['exit_multiplier']
# obtain trading filter info
if config['trading_filter']['active'] == 1:
    trading_filter = config['trading_filter']
else:
    trading_filter = None

# %%
n_years_train = round(len(df_prices_train)/240)

# %% [markdown]
# **Applying Bollinger Bands**

# %%
sharpe_results_bollinger, cum_returns_bollinger, performance_bollinger = trader.apply_bollinger_strategy(pairs,
                                                                                         lookback_multiplier,
                                                                                         entry_multiplier,
                                                                                         exit_multiplier,
                                                                                         trading_filter,
                                                                                         test_mode=False
                                                                                         )

# %% [markdown]
# **Bollinger Bands Performance**

# %%
avg_sharpe_bollinger, total_roi_bollinger, anual_roi_bollinger, positive_pct_bollinger = \
    trader.calculate_metrics(sharpe_results_bollinger, cum_returns_bollinger, n_years_train)
# Out:
# Average result:  0.82311767157538
# avg_total_roi:  9.497435796285458
# avg_annual_roi:  2.2941945816970177
# 95.65217391304348 % of the pairs had positive returns

# %% [markdown]
# **Applying the Kalman filter based strategy**

# %%
entry_multiplier= config['trading']['entry_multiplier']
exit_multiplier= config['trading']['exit_multiplier']
sharpe_results_kalman, cum_returns_kalman, performance_kalman = trader.apply_kalman_strategy(pairs, 
                                                                                             entry_multiplier,
                                                                                             exit_multiplier,
                                                                                             trading_filter,
                                                                                             test_mode=False)

# %%
avg_sharpe_kalman, total_roi_kalman, anual_roi_kalman, positive_pct_kalman = \
    trader.calculate_metrics(sharpe_results_kalman, cum_returns_kalman, n_years_train)
# Out:
# Average result:  1.9556001397873508
# avg_total_roi:  13.88491456705074
# avg_annual_roi:  3.3038601504925103
# 73.91304347826087 % of the pairs had positive returns

# %%
print('Sharpe Ratio Distribution: ')
n, bins, patches = plt.hist(sharpe_results_kalman, bins = 16, normed=True, orientation='vertical',
                            color='red', rwidth=0.9, align='mid')
# Out:
# Sharpe Ratio Distribution:

# %% [markdown]
# ## Some remarks
#
# - From the analysis above, the Kalman filter method obtains the best performance, with an average Sharpe Ratio larger than 1.
# - We should compare this approach with a *compare all against all* approach, to see by which factor our results are improved due to the clustering technique.

# %% [markdown]
# # Out of Sample Analysis
#
# In this section, we analyze the performance of the strategy in the validation dataset.
#
# We proceed with some data exploration analysis. For this purpose we will do the following:
#
# - Analyze which percentage of the identified pairs are still cointegrated in the validation period.
# - Analyze which percentage of pairs have positive returns, and how many of those are still cointegrated.
# - Analyze how many new pais were not identified to be cointegrated up to the validation period.
# - Run strategy for identified pairs in training period.
#
# This analysis will help us getting some insight into how the cointegrated pairs vary from time to time, and therefore how we should allocate our resources to predict when pairs are not cointegrated anymore.

# %% [markdown]
# ## Applying the Strategy out-of Sample
#
# We might want to apply the strategy in all pairs identified. Or, instead, we might prefer to apply the strategy only on those pairs that turned out to be profitable. Let's compare how both approaches work:

# %%
n_years_test = round(len(df_prices_test)/240)

# %% [markdown]
# ### Approach 1: Keeping every pair

# %% [markdown]
# **Bollinger Bands Out-of-Sample**

# %%
sharpe_results_bollinger_test, cum_returns_bollinger_test, performance_bollinger_test =\
                                    trader.apply_bollinger_strategy(pairs,
                                                                    lookback_multiplier,
                                                                    entry_multiplier,
                                                                    exit_multiplier,
                                                                    trading_filter,
                                                                    test_mode = True
                                                                    )

# %%
avg_sharpe_bollinger_test, total_roi_bollinger_test, anual_roi_bollinger_test, positive_pct_bollinger_test = \
    trader.calculate_metrics(sharpe_results_bollinger_test, cum_returns_bollinger_test, n_years_test)
# Out:
# Average result:  0.11057334467188644
# avg_total_roi:  -0.39719724064643
# avg_annual_roi:  -0.19879622000866792
# 47.82608695652174 % of the pairs had positive returns

# %% [markdown]
# **Kalman Out-of-Sample**

# %%
sharpe_results_kalman_test, cum_returns_kalman_test, performance_kalman_test = trader.apply_kalman_strategy(pairs, 
                                                                                             entry_multiplier,
                                                                                             exit_multiplier,
                                                                                             trading_filter,
                                                                                             test_mode=True)

# %%
avg_sharpe_kalman_test, total_roi_kalman_test, anual_roi_kalman_test, positive_pct_kalman_test = \
        trader.calculate_metrics(sharpe_results_kalman_test, cum_returns_kalman_test, n_years_test)
# Out:
# Average result:  1.9725581198159834
# avg_total_roi:  14.55576931856791
# avg_annual_roi:  7.030728913974937
# 73.91304347826087 % of the pairs had positive returns

# %% [markdown]
# ### Approach 2: Keeping only pairs that had positive returns in the training period

# %% [markdown]
# **Bollinger Strategy**

# %%
sharpe_results_bollinger = np.asarray(sharpe_results_bollinger)
profitable_pairs_indices = np.argwhere(sharpe_results_bollinger > 0)
profitable_pairs = [pairs[i] for i in profitable_pairs_indices.flatten()]

# %%
sharpe_results_bollinger_test, cum_returns_bollinger_test, performance_bollinger_test =\
                                    trader.apply_bollinger_strategy(profitable_pairs,
                                                                    lookback_multiplier,
                                                                    entry_multiplier,
                                                                    exit_multiplier,
                                                                    trading_filter,
                                                                    test_mode = True)

# %%
avg_sharpe_bollinger_test, total_roi_bollinger_test, anual_roi_bollinger_test, positive_pct_bollinger_test = \
    trader.calculate_metrics(sharpe_results_bollinger_test, cum_returns_bollinger_test, n_years_test)
# Out:
# Average result:  0.04814184192359454
# avg_total_roi:  -0.681003219793866
# avg_annual_roi:  -0.34108329898114853
# 45.45454545454545 % of the pairs had positive returns

# %% [markdown]
# **Kalman Strategy**

# %%
sharpe_results_kalman = np.asarray(sharpe_results_kalman)
profitable_pairs_indices = np.argwhere(sharpe_results_kalman > 0)
profitable_pairs = [pairs[i] for i in profitable_pairs_indices.flatten()]

# %%
sharpe_results_kalman_test, cum_returns_kalman_test, performance_kalman_test = trader.apply_kalman_strategy(\
                                                                                             profitable_pairs, 
                                                                                             entry_multiplier,
                                                                                             exit_multiplier,
                                                                                             trading_filter,
                                                                                             test_mode=True)

# %%
avg_sharpe_kalman_test, total_roi_kalman_test, anual_roi_kalman_test, positive_pct_kalman_test = \
    trader.calculate_metrics(sharpe_results_kalman_test, cum_returns_kalman_test, n_years_test)
# Out:
# Average result:  2.2228672288443327
# avg_total_roi:  15.117615725997423
# avg_annual_roi:  7.292877548324439
# 70.58823529411765 % of the pairs had positive returns

# %% [markdown]
# We can conclude that the 2nd approach presents better results. From now on, we assume the 2nd approach was taken.

# %% [markdown]
# ## Validate the results
#
# The results obtained are suspiciously high. We pretend to look deeper into the numbers.

# %%
results, pairs_summary = trader.summarize_results(sharpe_results_bollinger_test, cum_returns_bollinger_test,
                                                  performance_bollinger_test, positive_pairs)
# Out:
# Average result:  0.258071736592486
# avg_total_roi:  -9.856844008284336
# avg_annual_roi:  -5.05625034173357
# 52.459016393442624 % of the pairs had positive returns
# [ 0 15 32  1 44 20  8 23 31  2  3 36 14 38  9 33 35 46 27 24 21 18  4 17
#  22 30  7 45 26 41 28 58 19 40 48  6 60 34 10 49 54 29 47 55 56 59 50 25
#  37 43 16 53 42 57 13  5 51 52 39 12 11]

# %%
pairs_summary.head()
# Out:
#    Leg1  Leg2  t_statistic   p_value  zero_cross  half_life  hurst_exponent  \
# 0   AMJ  AMLP    -3.907799  0.001978         101         18        0.361325
# 1  MLPA  MLPI    -3.367611  0.012114          39         33        0.303600
# 2   DJP  SOYB    -3.014260  0.033584          56         27        0.419638
# 3   AMJ  MLPA    -3.687277  0.004296          58         22        0.372147
# 4   GSC   RJN    -4.089844  0.001007          96         15        0.333939
#
#    positive_trades  negative_trades  sharpe_result  \
# 0               15               11       1.843280
# 1               18               12       1.791256
# 2               17               10       1.680690
# 3               18               11       1.664013
# 4               20                9       1.583815
#
#    negative_trades_per_pair_pct
# 0                     42.307692
# 1                     40.000000
# 2                     37.037037
# 3                     37.931034
# 4                     31.034483

# %%
performance_bollinger_test[51][1].position_return.argmax()
# Out:
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   if __name__ == '__main__':
# Timestamp('2018-05-02 00:00:00')

# %%
test = performance_bollinger_test[51][1]
#test = test[test.position_return == -556.7363929256384]
test = test.loc['2018-04-30':'2018-05-04']
test
# Out:
#                  pnl       ret    spread   RJN     OIL    zscore  \
# Date
# 2018-04-30  0.030000  0.005569  0.783243  3.11  7.6100 -1.890525
# 2018-05-01 -0.030000 -0.005518  0.668609  3.08  7.6100 -2.077417
# 2018-05-02  2.363163  0.430340  3.030806  3.08  0.1522  3.832128
# 2018-05-03  0.010905  0.003485  3.070328  3.07  0.1550  2.802453
# 2018-05-04 -0.070002 -0.022800  3.140555  3.14  0.1560  2.317329
#
#             current_position  position_return (%)  position_return
# Date
# 2018-04-30               1.0                    0              NaN
# 2018-05-01               1.0                    0              NaN
# 2018-05-02               1.0                    0        43.327027
# 2018-05-03              -1.0                    0              NaN
# 2018-05-04              -1.0                    0              NaN

# %%
(np.cumprod(1 + test.ret) - 1)[-1] * 100 # HA DADOS CLARAMENTE ERRADOS!!!
# Out:
# -556.7363929256384

# %% [markdown]
# ## Analyzing Pairs' Overlap

# %% [markdown]
# There could be two possible interpretations for pairs' overlap.
# 1. We might be interested in checking which of the cointegrated pairs found in the training dataset are also cointegrated in the test set; Furthermore we want to explore how the two types of pairs perform.
# 2. We might be interested in finding if the pairs that would have been found in the test set by performing PCA + clustering would be cointegrated in the training set.

# %% [markdown]
# Starting with **1)**, let's see how many of the identified pairs actually turned out to be cointegrated during this period.

# %%
pairs_overlapped, pairs_overlapped_index = series_analyser.pairs_overlap(pairs,
                                  config['pair_restrictions']['p_value_threshold'],
                                  config['pair_restrictions']['min_zero_crossings'],
                                  config['pair_restrictions']['min_half_life'],
                                  config['pair_restrictions']['hurst_threshold'])
print('{} of the {} pairs identified in the training set are also cointegrated in the test set'.format(\
    len(pairs_overlapped), len(pairs)))
# Out:
# 20 of the 123 pairs identified in the training set are also cointegrated in the test set

# %%
positive_pairs_overlapped, positive_pairs_overlapped_index = series_analyser.pairs_overlap(positive_pairs, config['pair_restrictions']['p_value_threshold'],
                                  config['pair_restrictions']['min_zero_crossings'],
                                  config['pair_restrictions']['min_half_life'],
                                  config['pair_restrictions']['hurst_threshold'])
print('{} of the {} pairs with positive returns identified in the training set are also cointegrated in the test set'.format(\
    len(positive_pairs_overlapped), len(positive_pairs)))
# Out:
# 13 of the 97 pairs with positive returns identified in the training set are also cointegrated in the test set

# %% [markdown]
# ### Is cointegration really important?
#
# To answer this question we will see how many of the still cointegrated pairs had positive and negative returns. We will then do the same for those pairs that were not cointegrated.
#
# If both are as likely to have positive and negative returns, then it means cointegration is not as important of a condition. On the other hand, if we verify that all pairs that are still cointegrated turned out to be profitable and those that are not anymore led to consistent negative returns, we can infer that cointegration es a very important predictor of future returns.
#
# We also compare the average performance of the two groups two see the relevance of being cointegrated with respect to the sharpe ratio obtained.

# %% [markdown]
# *Still cointegrated*

# %%
# distribution for pairs which were cointegrated in train and test
sharpe_results_pairs_overlapped = np.asarray([sharpe_results_kalman_test[index] for index \
                                              in positive_pairs_overlapped_index])
cum_returns_pairs_overlapped = np.asarray([cum_returns_kalman_test[index] for index \
                                              in positive_pairs_overlapped_index])

_,_,_,_ = trader.calculate_metrics(sharpe_results_pairs_overlapped, cum_returns_pairs_overlapped,
                                   n_years_test)
# Out:
# Average result:  1.3363417505265678
# avg_total_roi:  8.306334837855852
# avg_annual_roi:  4.070329507432557
# 84.61538461538461 % of the pairs had positive returns

# %% [markdown]
# *Not cointegrated anymore*

# %%
# distribution for pairs which were cointegrated in train but not in test
positive_pairs_not_overlapped_index = [i for i in np.arange(0,len(positive_pairs))\
                                       if i not in positive_pairs_overlapped_index]

sharpe_results_pairs_not_overlapped = np.asarray([sharpe_results_kalman_test[index] for index \
                                              in positive_pairs_not_overlapped_index])

cum_returns_pairs_not_overlapped = np.asarray([cum_returns_kalman_test[index] for index \
                                              in positive_pairs_not_overlapped_index])

_,_,_,_ = trader.calculate_metrics(sharpe_results_pairs_not_overlapped, cum_returns_pairs_not_overlapped,
                                   n_years_test)
# Out:
# Average result:  1.3097308063641762
# avg_total_roi:  21.65310833213161
# avg_annual_roi:  10.29646790905483
# 75.0 % of the pairs had positive returns

# %% [markdown]
# Answering to the first question we were concerned with, we verify that a cointegrated pair is indeed more likely to have a positive return (84.6% vs 75%). Furthermore,what we can conclude from the results above is that being cointegrated did not imply that those pairs generated higher returns. In fact, the average annual return is higher for the pairs that were not found to be cointegrated in the testing period (4.07% vs 10.3%)
#
# **Conclusion**: The fact that a pair is not cointegrated anymore does not impact the results obained. In fact, we just concluded that betting solely on the cointegrated pairs would yield a worse result. Therefore, we should not spend much effort in detecting pairs that are no cointegrated anymore.

# %% [markdown]
# Following with point number **2)**, we proceed to analyze the performance of the pairs that woud have been identified in the testing period.

# %%
initial_test_date = config['dataset']['testing_initial_date']
final_teste_date = config['dataset']['testing_final_date']

# Get returns for test period
df_returns_test = data_processor.get_return_series(df_prices_test)

# Apply PCA
X_test, explained_variance_test = series_analyser.apply_PCA(N_PRIN_COMPONENTS, df_returns_test)
# Apply clustering
clustered_series_all_test, clustered_series_test, counts_test, clf_test = \
    series_analyser.apply_DBSCAN(config['clustering']['epsilon'],
                                 config['clustering']['min_samples'],
                                 X_test, df_returns_test)
# Find pairs
pairs_test, unique_tickers_test = series_analyser.get_candidate_pairs(\
                                            clustered_series=clustered_series_test,
                                            pricing_df_train=df_prices_test,
                                            pricing_df_test=df_prices_train,
                                            n_clusters=len(counts_test),
                                            min_half_life=config['pair_restrictions']['min_half_life'],
                                            min_zero_crosings=config['pair_restrictions']['min_zero_crossings'],
                                            p_value_threshold=config['pair_restrictions']['p_value_threshold'],
                                            hurst_threshold=config['pair_restrictions']['hurst_threshold']
                                            )

# Finally, see overlap
pairs_overlapped, pairs_overlapped_index = pairs_overlap(pairs_test,
                                  config['pair_restrictions']['p_value_threshold'],
                                  config['pair_restrictions']['min_zero_crossings'],
                                  config['pair_restrictions']['min_half_life'],
                                  config['pair_restrictions']['hurst_threshold'])
print('{} of the {} pairs identified in the test set are also cointegrated in the training set'.format(\
    len(pairs_overlapped), len(pairs_test)))
# Out:
# Clusters discovered: 15
# Pairs to evaluate: 110
# Found 15 pairs
# The pairs contain 20 unique tickers
# 3 of the 15 pairs identified in the test set are also cointegrated in the training set

# %% [markdown]
# Let's see if the pairs identified in the test period lead indeed to improved results:

# %%
sharpe_results_kalman_test_newpairs, cum_returns_kalman_test_newpairs, performance_kalman_test_newpairs =\
    trader.apply_kalman_strategy(pairs_test, entry_multiplier,exit_multiplier,trading_filter, test_mode=False)

_,_,_,_ = trader.calculate_metrics(sharpe_results_kalman_test_newpairs, cum_returns_kalman_test_newpairs,
                                   n_years_test)
# Out:
# Average result:  1.7011473917203828
# avg_total_roi:  9.387503774023532
# avg_annual_roi:  4.588481093294172
# 86.66666666666667 % of the pairs had positive returns

# %% [markdown]
# Even though the results are very positive, they are not so profitable as the pairs identified previously. This might be linked with the fact that these pairs did not prove to be cointegrated for a period as long as the other and therefore the pairs might be less stable.

# %% [markdown]
# ### The Correlation Filter
#
# The correlation filter aims to track how the correlation between the two legs of tha pair is varing, and provide that information as input to the trading strategy.

# %%
example_pair = failed_pairs[2]

example_pair_leg1 = example_pair[0][0]
example_pair_leg2 = example_pair[0][1]

example_pair_prices = etfs_pricing[[example_pair_leg1, example_pair_leg2]]
example_pair_prices.plot(figsize=(15,5))


# proceed to calculate correlation
rolling_window = config['trading']['lookback_multiplier']*example_pair[0][2]['half_life']

# get returns
example_pair_returns = data_processor.get_return_series(example_pair_prices)

# analyze correlation on returns
example_correlation = example_pair_returns[example_pair_leg1].rolling(rolling_window).corr(example_pair_returns[example_pair_leg2])

# plot correlation of returns
diff_example_correlation = example_correlation.diff(periods=1)
#diff_example_correlation = diff_example_correlation*10
diff_example_correlation.plot()

# %% [markdown]
# This result indicates there's almost no correlation between correlation diff and returns... Let's see how this result varies on average:

# %%
failure_correlations = []
for failure in failed_pairs:
    failure_df = failure[1][failure[1].units != 0]
    correlation = failure_df['ret'].corr(failure_df['correlation'])
    failure_correlations.append(correlation)
    
print(np.mean(failure_correlations))
# Out:
# -0.04480324434678721

# %% [markdown]
# However, we are not realyy interested in the correlation of the the diff column, but rather on the correlation with its sign.

# %%
failure_correlations = []
for failure in failed_pairs:
    failure_df = failure[1][failure[1].units != 0]
    failure_df['diff_correlation_sign']=failure_df['diff_correlation'].apply(lambda row: -1 if row<0 else 1)
    correlation = failure_df['ret'].corr(failure_df['diff_correlation_sign'])
    failure_correlations.append(correlation)
    
print(np.mean(failure_correlations))
# Out:
# /Users/simaomoraessarmento/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.021426798923804273

# %% [markdown]
# We could use mutual information rather than correlation as the sign is discrete. What about the relation with the zscore evolution?

# %% [markdown]
# ### Analyze non-profitable pairs

# %%
sharpe_results_kalman = np.asarray(sharpe_results_kalman)
negative_pairs_indices = np.argwhere(sharpe_results_kalman < 0)
print('{} out of {} pairs turned out to be non-profitable'.format(len(negative_pairs_indices), len(pairs)))
# Out:
# 9 out of 50 pairs turned out to be non-profitable

# %% [markdown]
# Let's get some more information on the non-profitable pairs:

# %%
negative_pairs = [pairs[i] for i in negative_pairs_indices.flatten()]
negative_pairs = [(item[0], item[1]) for item in negative_pairs]
negative_pairs
# Out:
# [('IEO', 'IYE'),
#  ('BAL', 'GCC'),
#  ('BAL', 'USCI'),
#  ('DJP', 'GCC'),
#  ('BNO', 'UGA'),
#  ('DBE', 'UGA'),
#  ('UGA', 'USL'),
#  ('UGA', 'USO'),
#  ('CORN', 'JJG')]

# %% [markdown]
# To what clusters do these pairs belong?

# %%
for label_n in range(len(counts)):
    elements_cluster_n = list(clustered_series[clustered_series == label_n].index)
    etfs_cluster_n = etfs_unique[etfs_unique['Ticker'].isin(elements_cluster_n)]
    for pair in negative_pairs:
        if pair[0] in list(etfs_cluster_n.Ticker):
            print('Pair {} belongs to cluster {}'.format(pair, label_n))
# Out:
# Pair ('IEO', 'IYE') belongs to cluster 0
# Pair ('BAL', 'GCC') belongs to cluster 1
# Pair ('BAL', 'USCI') belongs to cluster 1
# Pair ('DJP', 'GCC') belongs to cluster 1
# Pair ('BNO', 'UGA') belongs to cluster 3
# Pair ('DBE', 'UGA') belongs to cluster 3
# Pair ('UGA', 'USL') belongs to cluster 3
# Pair ('UGA', 'USO') belongs to cluster 3
# Pair ('CORN', 'JJG') belongs to cluster 5

# %% [markdown]
# How do the statistics rank?

# %%
sorted_indices = np.flip(np.argsort(sharpe_results_bollinger), axis=0)

# initialize list of lists 
data = []
for index in sorted_indices:
    # get number of positive and negative positions
    position_returns = performance_bollinger[index][1].position_return
    positive_positions = len(position_returns[position_returns>0])
    negative_positions = len(position_returns[position_returns<0])
    data.append([pairs[index][0],
                 pairs[index][1],
                 pairs[index][2]['t_statistic'],
                 pairs[index][2]['p_value'],
                 pairs[index][2]['zero_cross'],
                 pairs[index][2]['half_life'],
                 pairs[index][2]['hurst_exponent'],
                 positive_positions,
                 negative_positions,
                 sharpe_results_bollinger[index]
                ])
      
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['Leg1', 'Leg2', 't_statistic', 'p_value', 'zero_cross',
                                   'half_life', 'hurst_exponent', 'positive trades', 'negative_trades',
                                   'sharpe_result']) 
df
# Out:
#     Leg1  Leg2  t_statistic   p_value  zero_cross  half_life  hurst_exponent  \
# 0   CORN   GRU    -3.404058  0.010821         104         28        0.419100
# 1    RJN   USL    -2.988861  0.035948         114         35        0.439754
# 2    RJA  SOYB    -4.474279  0.000219          98         21        0.360609
# 3    RJN   USO    -3.351293  0.012736          95         37        0.439245
# 4    JJC   JJM    -3.097372  0.026748          80         22        0.329256
# 5    GRU  WEAT    -3.909307  0.001967         106         37        0.466337
# 6    DBO   RJN    -3.365444  0.012195         115         30        0.427794
# 7    DGP   UGL    -3.205752  0.019654          73         14        0.335867
# 8    JJA  WEAT    -3.117105  0.025313          74         54        0.444761
# 9   DJCI   GCC    -3.167705  0.021932          81         21        0.361562
# 10   DBA  SOYB    -4.255625  0.000530          61         34        0.394112
# 11   IYE  MLPG    -3.278068  0.015888          94         30        0.420731
# 12  PSCE   XOP    -3.033797  0.031856          53         44        0.424260
# 13  MLPG   VDE    -3.290072  0.015328          96         31        0.427004
# 14   FXN  MLPY    -3.215069  0.019129          73         42        0.445757
# 15  MLPG   XLE    -3.383444  0.011536          85         27        0.424831
# 16   IEO  MLPG    -3.043743  0.031006          92         42        0.442201
# 17  MLPY   PXE    -2.887882  0.046775          63         66        0.450516
# 18   CGW   NLR    -3.455682  0.009201         109         44        0.381354
# 19   BNO   DBO    -3.288865  0.015384          57         58        0.488000
# 20   DBO   USL    -3.047539  0.030687          75         40        0.481258
# 21   BNO   USL    -3.412421  0.010543          71         57        0.477356
# 22   NLR   PIO    -3.088739  0.027398          59         51        0.377173
# 23  CORN  WEAT    -4.025009  0.001285         103         28        0.360880
# 24   DGL  GLTR    -3.526009  0.007344         119         39        0.389798
# 25   DBP   DGL    -4.012179  0.001348         108         22        0.351349
# 26   FIW   NLR    -2.898705  0.045499          61         59        0.359898
# 27   DBO   UGA    -4.103609  0.000955          93         42        0.421711
# 28  GLTR  SGOL    -2.890758  0.046433          46         55        0.381446
# 29   BNO   DBE    -3.862296  0.002331          71         41        0.483531
# 30   IEZ  MLPY    -3.235804  0.018003          61         45        0.472852
# 31   BNO   RJN    -3.219686  0.018873          81         35        0.467922
# 32   RJN   UGA    -4.596536  0.000131         113         31        0.384388
# 33  MLPY   OIH    -3.110121  0.025813          57         49        0.476261
# 34   FXN   PXE    -3.119949  0.025112          41         80        0.471812
# 35   PXI   RYE    -3.114237  0.025517          80         37        0.372514
# 36   GLD  GLTR    -2.885500  0.047060          44         56        0.381921
# 37   BAL   DJP    -3.106978  0.026041          20         59        0.425694
# 38   JJG  WEAT    -3.888297  0.002123          86         50        0.461340
# 39   GSC   RJI    -3.281891  0.015708         121         17        0.390176
# 40   BAL  DJCI    -3.112129  0.025668          20         59        0.425149
# 41   BAL  USCI    -3.047555  0.030686          20         64        0.440896
# 42   BAL   GCC    -2.974045  0.037390          28         62        0.425347
# 43   IEO   IYE    -3.394124  0.011161          33         47        0.359826
# 44   DBE   UGA    -4.397291  0.000300          95         37        0.395641
# 45  CORN   JJG    -3.383709  0.011527          72         59        0.476036
# 46   UGA   USO    -4.169990  0.000740          97         43        0.417307
# 47   DJP   GCC    -3.114905  0.025470          53         52        0.417421
# 48   BNO   UGA    -4.246333  0.000550          93         33        0.388109
# 49   UGA   USL    -3.923622  0.001868          65         48        0.427001
#
#     positive trades  negative_trades  sharpe_result
# 0                19               14       7.874875
# 1                16                9       7.050578
# 2                20               22       5.984475
# 3                16                6       5.897631
# 4                24               15       5.699725
# 5                16                7       5.586175
# 6                17               10       5.496269
# 7                39               28       3.986749
# 8                 7                7       3.866423
# 9                27               14       3.568772
# 10               15                7       3.486162
# 11               14               16       3.475238
# 12                7                8       3.167081
# 13               18               11       3.147035
# 14                8               11       3.027819
# 15               13               18       3.017566
# 16               12                9       2.584272
# 17                8                7       2.556100
# 18                6               17       2.192494
# 19                4                9       2.178522
# 20                9                7       2.058656
# 21                8                7       2.001693
# 22                7               13       1.871397
# 23               15               12       1.728348
# 24                6                9       1.722381
# 25               21               16       1.689305
# 26                8                7       1.675642
# 27               12                6       1.615202
# 28                7                5       1.360648
# 29               11               13       1.288539
# 30                8               13       1.250557
# 31               15                7       1.104498
# 32               16               11       0.858657
# 33                9               10       0.828636
# 34                2                6       0.661299
# 35               11               10       0.659483
# 36                7                5       0.593121
# 37               10                3       0.474768
# 38               11                4       0.360969
# 39               31               27       0.208896
# 40                9                4       0.069932
# 41                6                6      -0.144719
# 42                8                5      -0.202569
# 43                7               10      -0.260172
# 44               13                8      -0.550752
# 45                9                2      -0.632221
# 46               10                9      -0.710138
# 47                7                6      -1.025779
# 48               14               14      -1.252192
# 49               10                8      -1.643437

# %%
df.half_life.mean()
# Out:
# 42.28

# %%
# analyze correlations
print('Half-life vs Sharpe Ratio correlation: ', df['sharpe_result'].corr(df['half_life']))
print('Zero crossings vs Sharpe Ratio correlation: ', df['sharpe_result'].corr(df['zero_cross']))
print('p-value vs Sharpe Ratio correlation: ', df['sharpe_result'].corr(df['p_value']))
print('t-statistic vs Sharpe Ratio correlation: ', df['sharpe_result'].corr(df['t_statistic']))
print('Hurst exponent vs Sharpe Ratio correlation ', df['sharpe_result'].corr(df['hurst_exponent']))
# Out:
# Half-life vs Sharpe Ratio correlation:  -0.4545065959240087
# Zero crossings vs Sharpe Ratio correlation:  0.41834257704466227
# p-value vs Sharpe Ratio correlation:  0.02552538602418196
# t-statistic vs Sharpe Ratio correlation:  0.09585827383877676
# Hurst exponent vs Sharpe Ratio correlation  -0.07104130200064852

# %% [markdown]
# Are there any signs these pairs were not profitable as the strategy evolves? Could we have predicted their lack of profitability?
# - Using a ML algorithm that recognizes when a pair is not profitable anymore.
# - Checking how the hurst exponent has been changing.
# - Analyze their previous positions' returns

# %% [markdown]
# # What if we haven't done any clustering?
#
# **All against all** - *comparing against the simplest strategy*

# %%
no_cluster_series = pd.Series(0,index = etfs_pricing.columns)
total_pairs_all_a_all, unique_tickers = series_analyser.get_candidate_pairs(clustered_series=no_cluster_series,
                                                            pricing_df=etfs_pricing,
                                                            n_clusters=1,
                                                            min_half_life=config['pair_restrictions']['min_half_life'],
                                                            min_zero_crosings=config['pair_restrictions']['min_zero_crossings'],
                                                            p_value_threshold=config['pair_restrictions']['p_value_threshold'],
                                                            hurst_threshold=config['pair_restrictions']['hurst_threshold']
                                                            )
pairs_found_all_a_all = len(total_pairs_all_a_all)
print('Found {} pairs'.format(pairs_found_all_a_all))
# Out:
# Found 273 pairs
# The pairs contain 41 unique tickers
# Found 273 pairs

# %% [markdown]
# Bollinger Bands:

# %%
lookback_multiplier= config['trading']['lookback_multiplier']
entry_multiplier= config['trading']['entry_multiplier']
exit_multiplier= config['trading']['exit_multiplier']
# obtain trading filter info
if config['trading_filter']['active'] == 1:
    trading_filter = config['trading_filter']
else:
    trading_filter = None

sharpe_results_boll_aaa, cum_returns_boll_aaa, performance_boll_aaa = trader.apply_bollinger_strategy(total_pairs_all_a_all,
                                                                                         lookback_multiplier,
                                                                                         entry_multiplier,
                                                                                         exit_multiplier,
                                                                                         trading_filter
                                                                                         )
# Out:
# ALTY,DBV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.019690076598853357
# Sharpe -0.37666046873915465
#
#
# ALTY,DIVA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.025647640984403308
# Sharpe -0.6268695474526955
#
#
# ALTY,FLAT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.08703113849382382
# Sharpe 2.030807685607455
#
#
# ALTY,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.00956969317643086
# Sharpe -0.24988167683679713
#
#
# ALTY,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03981804664306354
# Sharpe -1.0451248382719696
#
#
# ALTY,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04559781673716912
# Sharpe 0.9427153906928085
#
#
# ALTY,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04367292586973193
# Sharpe -0.5331008817168248
#
#
# ALTY,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.15845242756404643
# Sharpe 1.115245313399877
#
#
# ALTY,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.1815796270931438
# Sharpe 1.2097981203596972
#
#
# BTAL,DIVY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.017862582442937258
# Sharpe 0.5720161966008018
#
#
# BTAL,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.029607195121189145
# Sharpe 0.7547881999532214
#
#
# BTAL,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.013638947462838669
# Sharpe 0.448227225572819
#
#
# CHEP,DIVA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04564442310806638
# Sharpe 0.8075868719931734
#
#
# CHEP,DIVY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.023734801604629485
# Sharpe 0.8278376545038248
#
#
# CHEP,FTLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05475313592423159
# Sharpe -0.5285461968372713
#
#
# CHEP,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.07843386895838855
# Sharpe 0.9541164431730961
#
#
# CHEP,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.013066362393680198
# Sharpe -0.32656697810729557
#
#
# CHEP,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.15802456562677158
# Sharpe -2.2741225301007804
#
#
# CHEP,WTMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03704914288701411
# Sharpe 0.42791170203826184
#
#
# CPI,DBV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.016639724025610647
# Sharpe 0.451017253943422
#
#
# CPI,DIVA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.008148736318299932
# Sharpe -0.2529604024702721
#
#
# CPI,FLAT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01333365641280193
# Sharpe 0.3783583561924677
#
#
# CPI,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03179155436860104
# Sharpe -1.5239019260532503
#
#
# CPI,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.026829435523993195
# Sharpe -1.680451144650128
#
#
# CPI,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0019713533965743935
# Sharpe -0.06888483123444301
#
#
# CPI,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.006723704194581015
# Sharpe -0.37628752645933594
#
#
# CPI,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01231233939417753
# Sharpe -0.6503464386821005
#
#
# CPI,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.036767769830756136
# Sharpe -0.37259711446930555
#
#
# CPI,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.003033310651405996
# Sharpe 0.019667648442419652
#
#
# CPI,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0008009217228750476
# Sharpe 0.040376344862233016
#
#
# DBV,DIVA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01040391075537106
# Sharpe -0.21628239400375174
#
#
# DBV,DIVY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.020953322884465164
# Sharpe 0.6719961494448251
#
#
# DBV,FAAR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03748041970474558
# Sharpe 0.5819557886181744
#
#
# DBV,FLAT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.07005274749245327
# Sharpe 0.9724830605500115
#
#
# DBV,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.023098680887244427
# Sharpe 0.6449085110023693
#
#
# DBV,GAA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.013300768715592493
# Sharpe -0.26783025142068745
#
#
# DBV,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.026400026850126768
# Sharpe -0.8205279159785254
#
#
# DBV,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.021144824815402807
# Sharpe -0.7841388265961308
#
#
# DBV,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02486311210232839
# Sharpe -0.7367721352247024
#
#
# DBV,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05082067277166569
# Sharpe -1.271605943352887
#
#
# DBV,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.004602775548259164
# Sharpe -0.18597790263689942
#
#
# DBV,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.015746925722088356
# Sharpe 0.4000772223180287
#
#
# DBV,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.041042395774667506
# Sharpe 0.7636521450989657
#
#
# DBV,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.08382731696861301
# Sharpe 1.3829215380292141
#
#
# DBV,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.044942616223459186
# Sharpe 0.31870295183995884
#
#
# DBV,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.047111281530996196
# Sharpe 0.3259228017815967
#
#
# DBV,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0347281019670429
# Sharpe 0.7817699575573047
#
#
# DBV,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04851776846515543
# Sharpe 0.39309606535236463
#
#
# DBV,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.02738731957282048
# Sharpe 0.31904326434313524
#
#
# DBV,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.05448330211042851
# Sharpe 0.4290807790666731
#
#
# DBV,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0901801001583864
# Sharpe 1.4265518928972782
#
#
# DBV,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01802117791542468
# Sharpe 0.23520302967979578
#
#
# DIVA,FAAR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.02126890865414044
# Sharpe 0.4829682415171442
#
#
# DIVA,FLAT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.009148415857905934
# Sharpe -0.16009102571325132
#
#
# DIVA,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04365460565919732
# Sharpe 1.1126199457733978
#
#
# DIVA,GAA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05323678512217778
# Sharpe -1.3274581239340535
#
#
# DIVA,HDG
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0016090546167013553
# Sharpe -0.02415189416756278
#
#
# DIVA,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0008708313507430621
# Sharpe -0.0022123978448937327
#
#
# DIVA,MCRO
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.026141745296051067
# Sharpe -0.6789243855292437
#
#
# DIVA,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.018693332389417838
# Sharpe -0.4554574115303623
#
#
# DIVA,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.059439767755608774
# Sharpe -1.2168205157279068
#
#
# DIVA,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03502116644561315
# Sharpe -0.915416798813041
#
#
# DIVA,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01980254753702415
# Sharpe -0.5133581945405308
#
#
# DIVA,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.030852054765520553
# Sharpe -1.0657931587688623
#
#
# DIVA,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.026610114643958127
# Sharpe 0.7156257033905897
#
#
# DIVA,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.005068347932295936
# Sharpe 0.17713147756326209
#
#
# DIVA,RALS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.00018772807011280257
# Sharpe 0.02526143334356859
#
#
# DIVA,RINF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.045554115023159425
# Sharpe -0.9852954618389087
#
#
# DIVA,RLY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01896471359405061
# Sharpe -0.4051598950197042
#
#
# DIVA,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04684659395991919
# Sharpe 0.9843676193258001
#
#
# DIVA,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.08510554058169872
# Sharpe 1.4779415908917648
#
#
# DIVA,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04146312860638357
# Sharpe 0.5933366926315745
#
#
# DIVA,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.05205618217328323
# Sharpe 0.734026628385942
#
#
# DIVA,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05642056614856672
# Sharpe -1.564124480081488
#
#
# DIVA,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.11407931714193853
# Sharpe 1.9963207888977776
#
#
# DIVA,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.10549016666101863
# Sharpe 1.729224592760924
#
#
# DIVA,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.10904664755240456
# Sharpe 1.8996972497442384
#
#
# DIVA,WTMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.044035992860706585
# Sharpe 1.149769501876805
#
#
# DIVA,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.05254693458806314
# Sharpe 1.122031104003971
#
#
# DIVA,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.08165630755618969
# Sharpe -1.4003938728604428
#
#
# DIVY,DYB
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.024569195016881595
# Sharpe -0.9748186210390113
#
#
# DIVY,FMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03682071366157491
# Sharpe -1.2561063428888681
#
#
# DIVY,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0023236595019513473
# Sharpe 0.10140844604122988
#
#
# DIVY,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0010792588853065777
# Sharpe 0.05798618053133644
#
#
# DIVY,RALS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.014897058814055564
# Sharpe 0.6134765678481056
#
#
# DIVY,RINF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.012180046803939915
# Sharpe -0.345451646484425
#
#
# DIVY,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.001516939825051633
# Sharpe -0.04363421935821908
#
#
# DIVY,WTMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.026785394067421642
# Sharpe -1.0444658494839014
#
#
# DIVY,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.020872739118668715
# Sharpe 0.7337220357184145
#
#
# DYB,FAAR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03555596394225624
# Sharpe -0.6721083523206645
#
#
# DYB,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.041507885712658066
# Sharpe -0.726524431970236
#
#
# DYLS,FTLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.018902551289150082
# Sharpe -0.7222288832865508
#
#
# DYLS,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02802140994058322
# Sharpe -0.7952566005178304
#
#
# DYLS,HDG
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0009697049236687683
# Sharpe 0.0511894797081523
#
#
# DYLS,HTUS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.016696659566495686
# Sharpe -0.6691815598609906
#
#
# DYLS,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.019492685631331996
# Sharpe -0.7114861829423424
#
#
# DYLS,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04940924304318406
# Sharpe -1.5863830227040014
#
#
# DYLS,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04690604194608239
# Sharpe -1.536638946895653
#
#
# DYLS,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0056085359979249905
# Sharpe -0.05247985842201498
#
#
# FAAR,FMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03789674594761405
# Sharpe -0.7362066193504633
#
#
# FAAR,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0147795058563166
# Sharpe -0.4017143834237111
#
#
# FAAR,GAA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.052365731611748845
# Sharpe -0.7292400296314065
#
#
# FAAR,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.010165411701905214
# Sharpe 0.31245719509995007
#
#
# FAAR,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.017244596218970676
# Sharpe 0.3287712093912726
#
#
# FAAR,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.026378526082030063
# Sharpe -0.3781309974588313
#
#
# FAAR,RLY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.014105522825994088
# Sharpe 0.27053011718695585
#
#
# FAAR,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.038963960601968495
# Sharpe 0.665798981884166
#
#
# FAAR,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.05565760124645158
# Sharpe 0.6395541486296747
#
#
# FAAR,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04282431587647162
# Sharpe 0.4976626680561604
#
#
# FAAR,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.057659469307710265
# Sharpe -0.6402059304819429
#
#
# FLAT,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.023369530138971806
# Sharpe 0.7695874432530924
#
#
# FLAT,MCRO
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.020705898408010515
# Sharpe -0.39070956157318404
#
#
# FLAT,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0472056412657762
# Sharpe 1.043132063589479
#
#
# FLAT,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.02383901060688376
# Sharpe 0.516836877368102
#
#
# FLAT,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04235227506461592
# Sharpe 0.6338548571420459
#
#
# FLAT,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0908712652709277
# Sharpe -0.42215407780208114
#
#
# FLAT,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.08090608763340668
# Sharpe -0.36517748811518724
#
#
# FLAT,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04955146797558396
# Sharpe 0.5464269685671201
#
#
# FLAT,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04993346231985263
# Sharpe 0.5882647124996202
#
#
# FLAT,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04927652257980175
# Sharpe 0.543214264467099
#
#
# FLAT,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.07369725601873323
# Sharpe -0.8674475242248434
#
#
# FMF,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01184548122325313
# Sharpe -0.31346043340502394
#
#
# FTLS,FUT
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.02327006667528897
# Sharpe 0.6417075558923766
#
#
# FTLS,HDG
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.00285610714941531
# Sharpe 0.13979756678696828
#
#
# FTLS,HTUS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.009495237787841893
# Sharpe 0.42883263565905183
#
#
# FTLS,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.027685773313176343
# Sharpe -1.0619423590261612
#
#
# FTLS,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.022507917728671112
# Sharpe -0.388510931639775
#
#
# FTLS,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05920148453970708
# Sharpe -2.3473015895789366
#
#
# FTLS,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.058135202806301134
# Sharpe -1.5463430684853752
#
#
# FTLS,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.3070828399374269
# Sharpe -2.728712713737295
#
#
# FTLS,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.050055429847703725
# Sharpe -0.9988937092811244
#
#
# FTLS,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04891985864377413
# Sharpe -0.974539481255331
#
#
# FTLS,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.013264208326657423
# Sharpe -0.2819939172430328
#
#
# FUT,GAA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03096986960422865
# Sharpe 0.9009555733700528
#
#
# FUT,HTUS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.02303278694396793
# Sharpe 0.7388046003734902
#
#
# FUT,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04081425011189066
# Sharpe 1.572016704331324
#
#
# FUT,MCRO
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.00807815069318174
# Sharpe 0.297958642354598
#
#
# FUT,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0033786845322384407
# Sharpe -0.11191925393761408
#
#
# FUT,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.04525950443613991
# Sharpe 1.2925014335620562
#
#
# FUT,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01793785247566615
# Sharpe 0.7177366576557209
#
#
# FUT,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05365952144185904
# Sharpe -2.052228008273042
#
#
# FUT,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.015262384741230317
# Sharpe -0.4599074662859895
#
#
# FUT,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.007898676507078983
# Sharpe 0.33744439145744165
#
#
# FUT,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.011701496822161261
# Sharpe -0.27763578578786585
#
#
# FUT,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.008735844000838489
# Sharpe -0.18056608916994585
#
#
# FUT,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03348761812613865
# Sharpe -0.701280205107946
#
#
# FUT,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03202798418065267
# Sharpe -0.6713121003841697
#
#
# FUT,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01130011645109752
# Sharpe 0.36898880399202194
#
#
# FUT,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02163472840343761
# Sharpe -0.4724511827384777
#
#
# FUT,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.029667668383857926
# Sharpe -0.750752133328235
#
#
# FUT,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.023912294587060567
# Sharpe -0.5262292758766829
#
#
# FUT,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0026917894161992972
# Sharpe 0.09092123080685184
#
#
# GAA,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.035619201499040076
# Sharpe -1.2575124757597154
#
#
# GAA,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.018659978146204792
# Sharpe -0.8086066083012423
#
#
# GAA,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01928536010251858
# Sharpe -0.7202000815108774
#
#
# GAA,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.00845090691492767
# Sharpe 0.42384859520539125
#
#
# GAA,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.013779810487764887
# Sharpe -0.5368400951894414
#
#
# GAA,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.005464669396758937
# Sharpe -0.22223315334397822
#
#
# GAA,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.2023542924876791
# Sharpe -1.523621452192824
#
#
# GAA,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.20226212790474174
# Sharpe -1.4518841849221336
#
#
# GAA,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.10533187902946395
# Sharpe -1.8121634764028598
#
#
# GAA,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.10049542994659666
# Sharpe -1.5816493328055918
#
#
# HDG,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02244303848321727
# Sharpe -0.8197334387728287
#
#
# HDG,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.005044616654369061
# Sharpe -0.2491352904151918
#
#
# HDG,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02866338879531427
# Sharpe -0.5658744462176117
#
#
# HDG,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.013507080648306191
# Sharpe -0.43879097110722115
#
#
# HDG,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01770750640411556
# Sharpe -0.8903334702980927
#
#
# HTUS,JPHF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03508779139589191
# Sharpe -1.3961316637579069
#
#
# HTUS,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05237789635471335
# Sharpe -0.9605911550614926
#
#
# HTUS,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.022183631665040227
# Sharpe -0.8528221408724123
#
#
# JPHF,MCRO
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03412787259067529
# Sharpe -1.2894900173821024
#
#
# JPHF,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.023833632616770517
# Sharpe -0.9428301581666702
#
#
# JPHF,MOM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0045683647868053345
# Sharpe 0.15584087398421984
#
#
# JPHF,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0005290118028969948
# Sharpe -0.006615364134820804
#
#
# JPHF,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02373051994106723
# Sharpe -1.0107603628549136
#
#
# JPHF,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01996689792746187
# Sharpe -0.7244352873279398
#
#
# JPHF,RALS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.008257002530233093
# Sharpe -0.2826477491645487
#
#
# JPHF,RINF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01814730142512433
# Sharpe 0.5573094209734716
#
#
# JPHF,RLY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03450990221061068
# Sharpe -1.0437933023617363
#
#
# JPHF,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03981853159181559
# Sharpe 1.0868464584287867
#
#
# JPHF,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.003944604482825964
# Sharpe 0.12943915866420144
#
#
# JPHF,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.06381467319016831
# Sharpe -1.8129514606016026
#
#
# JPHF,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.07658771571109568
# Sharpe 2.0371226377824896
#
#
# JPHF,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.05730360513809485
# Sharpe 1.6661603576311264
#
#
# JPHF,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.07552852867874194
# Sharpe 1.9991526445700292
#
#
# JPHF,WTMF
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.01928446641330872
# Sharpe 0.6243987217173437
#
#
# JPHF,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.004978880798047869
# Sharpe -0.1416675745590903
#
#
# MCRO,MNA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.044239469899094885
# Sharpe -2.0885176924489355
#
#
# MCRO,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.007548907573814101
# Sharpe -0.3055623652858815
#
#
# MCRO,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02135238792292582
# Sharpe -1.2910818883253163
#
#
# MCRO,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.07616121123885033
# Sharpe 1.8122996378085268
#
#
# MCRO,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.12439821645715288
# Sharpe -1.2289952058701996
#
#
# MCRO,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.11996411157751374
# Sharpe -1.1819538098501103
#
#
# MCRO,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.005479678597650639
# Sharpe -0.0883742568092604
#
#
# MCRO,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.016534803558362343
# Sharpe -0.6948933109495854
#
#
# MNA,MRGR
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.042772481047270605
# Sharpe -1.7420997568262773
#
#
# MNA,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.029758639562709854
# Sharpe -1.4851231100158457
#
#
# MNA,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.044216003807129756
# Sharpe -2.1700497082470602
#
#
# MNA,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.028810665304430882
# Sharpe -1.2156909622290077
#
#
# MNA,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.033148208661512135
# Sharpe -1.6304147225551633
#
#
# MNA,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.011458415759262097
# Sharpe 0.40091680518302564
#
#
# MNA,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01104767493098513
# Sharpe -0.35664442759613796
#
#
# MNA,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.23912276535886245
# Sharpe -1.199030258589216
#
#
# MNA,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.28672377462857124
# Sharpe -1.5504418831513092
#
#
# MNA,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.024743814592359192
# Sharpe -1.0502076686306336
#
#
# MNA,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03360939211634384
# Sharpe 0.8987617039516559
#
#
# MNA,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.031560052556113716
# Sharpe 0.8232540108156807
#
#
# MNA,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.022780270316132167
# Sharpe 0.7999483838926853
#
#
# MNA,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.05309244144173597
# Sharpe -1.7050645354947593
#
#
# MOM,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.06338503702109777
# Sharpe -2.1737886560424227
#
#
# MOM,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.17228317345691957
# Sharpe -0.5554809421259133
#
#
# MOM,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.1987058073885467
# Sharpe -0.7160483875003189
#
#
# MOM,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.015207803828720112
# Sharpe -0.3069874371281602
#
#
# MRGR,QAI
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0218363270668418
# Sharpe -1.098622853595885
#
#
# MRGR,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.03358731056686115
# Sharpe 1.49121001717081
#
#
# MRGR,QLS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04216197980998637
# Sharpe -1.3801310317571565
#
#
# MRGR,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.021907669223178328
# Sharpe 1.0017397314908116
#
#
# MRGR,RALS
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0049716385770830485
# Sharpe -0.16633857151815518
#
#
# MRGR,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04215569703312971
# Sharpe -0.9905003145949858
#
#
# MRGR,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.020315236058495945
# Sharpe -0.5584291396847593
#
#
# MRGR,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.14271456923906012
# Sharpe 1.063037812486579
#
#
# MRGR,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03415502408097759
# Sharpe -0.2935927519805239
#
#
# MRGR,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03291055415174238
# Sharpe -1.1971773237387322
#
#
# MRGR,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.024747273654272095
# Sharpe -0.25629298187445104
#
#
# MRGR,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.027863839283402525
# Sharpe 0.43556627179367446
#
#
# MRGR,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.06824455373202598
# Sharpe 0.7377112916367486
#
#
# MRGR,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.04757952831183043
# Sharpe -1.538171968635446
#
#
# MRGR,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.060524091271701774
# Sharpe -1.7570944407672764
#
#
# QAI,QED
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.003137218456738422
# Sharpe -0.14264575090188372
#
#
# QAI,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.059032648884023486
# Sharpe -1.0660982516318558
#
#
# QAI,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03217483545109823
# Sharpe -1.2986564501373972
#
#
# QAI,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.030731210761018146
# Sharpe -1.2403232197312029
#
#
# QAI,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.01797237775896887
# Sharpe -0.2186763212818229
#
#
# QAI,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.06070123939526739
# Sharpe -2.2981623706377254
#
#
# QAI,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.005020843480048387
# Sharpe -0.039380989594672976
#
#
# QAI,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.028122844711868766
# Sharpe -0.4591496462626992
#
#
# QED,QMN
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.018909382877140724
# Sharpe -1.0387549981621107
#
#
# QED,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.08552744302507587
# Sharpe -2.286966524378461
#
#
# QED,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0010059667187531929
# Sharpe 0.05423353830889084
#
#
# QED,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.015252028502424797
# Sharpe -0.5556534693811954
#
#
# QLS,SIZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0011687049594665266
# Sharpe -0.002795623924050694
#
#
# QLS,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.016691145894728532
# Sharpe 0.42176693876875887
#
#
# QLS,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.2546657369316295
# Sharpe -1.1539901869231597
#
#
# QLS,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.2103246982301903
# Sharpe -0.9783940287884558
#
#
# QMN,SVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03297509154708733
# Sharpe -1.4875211804197424
#
#
# QMN,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.02865851500005756
# Sharpe -0.3584709363275031
#
#
# QMN,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.019166730544468047
# Sharpe 0.9134893812710597
#
#
# QMN,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.016195432001758547
# Sharpe -0.23569161898567167
#
#
# QMN,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.0659033498610695
# Sharpe 1.6456231881855503
#
#
# QMN,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.003910008120728725
# Sharpe -0.026521529935989704
#
#
# QMN,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.037125962698891346
# Sharpe 0.9644108454140994
#
#
# SIZ,STPP
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.018375473522315167
# Sharpe -0.2660397335543421
#
#
# SIZ,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.2007515737553518
# Sharpe 1.2289623815831083
#
#
# SIZ,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.20723306039641387
# Sharpe 1.2317896959829666
#
#
# SIZ,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03766003492336345
# Sharpe -0.4607250899520474
#
#
# SIZ,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.00788788002388019
# Sharpe -0.07975239619868232
#
#
# SIZ,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.03790394998009872
# Sharpe -0.46397250193885425
#
#
# SIZ,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.08434756632542939
# Sharpe 1.3964545425433257
#
#
# STPP,TVIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.4137631666153908
# Sharpe -1.5164772946893816
#
#
# STPP,UVXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.3934423748535184
# Sharpe -1.3986737636124698
#
#
# STPP,VIIX
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.19551069596928028
# Sharpe -0.9136430120470955
#
#
# STPP,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.044604974341915016
# Sharpe 0.45415770919415077
#
#
# STPP,VIXY
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.1991344005434147
# Sharpe -0.9335287454914163
#
#
# STPP,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.2235581231768805
# Sharpe -2.3852254136143043
#
#
# TVIX,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.12781076619854614
# Sharpe 0.967694694316533
#
#
# TVIX,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.030107075046490128
# Sharpe -0.16383633581407728
#
#
# TVIX,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.11805659011942726
# Sharpe 0.5190886067989029
#
#
# UVXY,VEGA
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.11959576123471938
# Sharpe 0.9102157036559749
#
#
# UVXY,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.0444710409582616
# Sharpe -0.27552171159037575
#
#
# UVXY,XVZ
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.44063357459775543
# Sharpe 1.0367498642915272
#
#
# VEGA,VIXM
# Warning: don't forget lookback (halflife) must be at least 3.
# APR 0.09727167638303924
# Sharpe 1.2950686313414943
#
#
# VIIX,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.08401676285230242
# Sharpe -0.8172407043595594
#
#
# VIXY,ZIV
# Warning: don't forget lookback (halflife) must be at least 3.
# APR -0.13274753935170802
# Sharpe -1.3632337600605549

# %%
print('Sharpe Ratio Results (considering entire universe): ')
n, bins, patches = plt.hist(sharpe_results_boll_aaa, bins = 16, normed=True, orientation='vertical',
                            color='red', rwidth=0.9, align='mid')
print('Average result: ', np.mean(sharpe_results_boll_aaa))
# Out:
# Sharpe Ratio Results (considering entire universe):
# Average result:  -0.2182626320695486

# %% [markdown]
# Kalman filter:

# %%
entry_multiplier=2
exit_multiplier=0.5

sharpe_results_kalman_all_a_all, cum_returns_kalman_all_all = apply_kalman_strategy(total_pairs_all_a_all,
                                                                                    entry_multiplier,
                                                                                    exit_multiplier)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-690-a9e0fe89bbe9> in <module>()
#       2 exit_multiplier=0.5
#       3
# ----> 4 sharpe_results_kalman_all_a_all, cum_returns_kalman_all_all = apply_kalman_strategy(total_pairs_all_a_all,
#       5                                                                                     entry_multiplier,
#       6                                                                                     exit_multiplier)
#
# NameError: name 'apply_kalman_strategy' is not defined

# %%
print('Sharpe Ratio Results (considering the entire universe): ')
n, bins, patches = plt.hist(sharpe_results_kalman_all_a_all, bins = 16, normed=True, orientation='vertical',
                            color='red', rwidth=0.9, align='mid')
print('Average result: ', np.mean(sharpe_results_kalman_all_a_all))
# Out:
# Sharpe Ratio Results (considering the entire universe):
# Average result:  0.2917998463678402

# %% [markdown]
# ## Data cleaning
#
# Detecting noisy data points:

# %%
def data_cleaning(df_prices, to_clean=[]):
    df_prices_filtered = df_prices.copy()

    # iterate over every day prices, and remove value if deviates too much from mean
    for ticker in df_prices_filtered.columns:
        average = df_prices_filtered[ticker].mean()
        std_deviation = df_prices_filtered[ticker].std()
        indices = df_prices_filtered[(df_prices_filtered[ticker]-average) > 5*std_deviation].index
        if len(indices) > 0:
            # remove elements corresponding to the beggining 
            if indices[0] == df_prices_filtered.index[0]:
                aux_index = 0
                while indices[0] == df_prices_filtered.index[aux_index]:
                    if len(indices)>1:
                        indices = indices[1:]               
                        aux_index += 1
                    else:
                        indices = []
                        break
            else:
                print(ticker)
                print(df_prices_filtered[ticker].loc[indices])
                if ticker in to_clean:
                    df_prices_filtered[ticker].loc[indices] = np.nan
                    df_prices_filtered[ticker] = df_prices_filtered[ticker].fillna(method='ffill')
                    print(df_prices_filtered[ticker].loc[indices])
                else:
                    print(ticker + ' not cleaned')
    
    return df_prices_filtered

# %%
_ = data_cleaning(df_prices, to_clean=[])
# Out:
# BAL
# Date
# 2018-05-01    100.0
# 2018-05-02    100.0
# 2018-05-03    100.0
# 2018-05-04    100.0
# 2018-05-07    100.0
# 2018-05-08    100.0
# 2018-05-09    100.0
# 2018-05-10    100.0
# 2018-05-11    100.0
# 2018-05-14    100.0
# 2018-05-15    100.0
# 2018-05-16    100.0
# 2018-05-17    100.0
# 2018-05-18    100.0
# 2018-05-21    100.0
# 2018-05-22    100.0
# 2018-05-23    100.0
# Name: BAL, dtype: float64
# BAL not cleaned
# COM
# Date
# 2014-05-07    33000.0
# 2014-05-08    33000.0
# 2014-05-09    32500.0
# 2014-05-23    32000.0
# 2014-06-02    32000.0
# 2014-06-04    32000.0
# 2014-06-05    32000.0
# 2014-06-20    30000.0
# 2014-07-23    33000.0
# 2015-02-02    31700.0
# 2015-02-03    33900.0
# 2015-02-04    33900.0
# 2015-02-09    38500.0
# 2015-02-17    39500.0
# 2015-03-04    42000.0
# 2015-04-06    36800.0
# 2015-04-22    36500.0
# 2015-04-23    36500.0
# 2015-04-24    36500.0
# 2015-04-27    36500.0
# 2015-04-29    36500.0
# 2015-05-04    36500.0
# 2015-05-05    35500.0
# 2015-05-06    35500.0
# 2015-05-07    35500.0
# 2015-06-09    31300.0
# 2015-07-15    35000.0
# 2015-08-06    35000.0
# 2015-08-13    32000.0
# 2015-08-19    33500.0
# 2015-08-27    34000.0
# 2015-10-12    41500.0
# 2016-07-27    44300.0
# Name: COM, dtype: float64
# COM not cleaned
# OIL
# Date
# 2018-05-08    1794.839966
# Name: OIL, dtype: float64
# OIL not cleaned

# %%
to_clean = ['OIL', 'BAL']
to_drop = ['COM']
df_prices_filtered = data_cleaning(df_prices, to_clean=to_clean)
df_prices_filtered = df_prices_filtered.drop(columns=to_drop)
# Out:
# BAL
# Date
# 2018-05-01    100.0
# 2018-05-02    100.0
# 2018-05-03    100.0
# 2018-05-04    100.0
# 2018-05-07    100.0
# 2018-05-08    100.0
# 2018-05-09    100.0
# 2018-05-10    100.0
# 2018-05-11    100.0
# 2018-05-14    100.0
# 2018-05-15    100.0
# 2018-05-16    100.0
# 2018-05-17    100.0
# 2018-05-18    100.0
# 2018-05-21    100.0
# 2018-05-22    100.0
# 2018-05-23    100.0
# Name: BAL, dtype: float64
# Date
# 2018-05-01    55.099998
# 2018-05-02    55.099998
# 2018-05-03    55.099998
# 2018-05-04    55.099998
# 2018-05-07    55.099998
# 2018-05-08    55.099998
# 2018-05-09    55.099998
# 2018-05-10    55.099998
# 2018-05-11    55.099998
# 2018-05-14    55.099998
# 2018-05-15    55.099998
# 2018-05-16    55.099998
# 2018-05-17    55.099998
# 2018-05-18    55.099998
# 2018-05-21    55.099998
# 2018-05-22    55.099998
# 2018-05-23    55.099998
# Name: BAL, dtype: float64
# COM
# Date
# 2014-05-07    33000.0
# 2014-05-08    33000.0
# 2014-05-09    32500.0
# 2014-05-23    32000.0
# 2014-06-02    32000.0
# 2014-06-04    32000.0
# 2014-06-05    32000.0
# 2014-06-20    30000.0
# 2014-07-23    33000.0
# 2015-02-02    31700.0
# 2015-02-03    33900.0
# 2015-02-04    33900.0
# 2015-02-09    38500.0
# 2015-02-17    39500.0
# 2015-03-04    42000.0
# 2015-04-06    36800.0
# 2015-04-22    36500.0
# 2015-04-23    36500.0
# 2015-04-24    36500.0
# 2015-04-27    36500.0
# 2015-04-29    36500.0
# 2015-05-04    36500.0
# 2015-05-05    35500.0
# 2015-05-06    35500.0
# 2015-05-07    35500.0
# 2015-06-09    31300.0
# 2015-07-15    35000.0
# 2015-08-06    35000.0
# 2015-08-13    32000.0
# 2015-08-19    33500.0
# 2015-08-27    34000.0
# 2015-10-12    41500.0
# 2016-07-27    44300.0
# Name: COM, dtype: float64
# COM not cleaned
# OIL
# Date
# 2018-05-08    1794.839966
# Name: OIL, dtype: float64
# Date
# 2018-05-08    0.1596
# Name: OIL, dtype: float64

# %%
# update df prices
df_prices = df_prices_filtered
